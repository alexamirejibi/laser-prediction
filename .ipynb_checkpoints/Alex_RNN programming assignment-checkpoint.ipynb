# %% [markdown]
# # 1 Dataset and Task
#  (a) Select your choice of neural networks model that is suitable for this task and motivate it. Train your model
#  to predict one step ahead data point, during training (see following Figure). Scale your data before training
#  and scale them back to be able to compare your predictions with real measurements.
#
#  (b) How many past time steps should you input into your network to achieve the best possible performance?
#  (Hint: This is a tunable parameter and needs to be tuned).
#
#  (c) Once your model is trained, use it to predict the next 200 data points recursively. This means feeding each
#  prediction back into the model to generate the subsequent predictions.)
#
#  (d) On May 9th, download the real test dataset and evaluate your model by reporting both the Mean Absolute
#  Error (MAE) and Mean Squared Error (MSE) between its predictions and the actual test values. Additionally,
#  create a plot comparing the predicted and real values to visually assess your models performance.

# %% [markdown]
# First, we load the data and take a look at it. We also install torch:

# %%
file = 'Xtrain.mat'
# load training data
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn

# Load the training data
data = scipy.io.loadmat(file)
X_train = data['Xtrain']

# Display basic information about the data
print(f"Data shape: {X_train.shape}")
print(f"Data type: {X_train.dtype}")
print(f"Min value: {np.min(X_train)}")
print(f"Max value: {np.max(X_train)}")

# plot the data
plt.plot(X_train)
plt.ylabel('Amplitude (uint8)')
plt.xlabel('Time')
plt.show()

file = 'Xtest.mat'
# load training data
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn

# Load the training data
data = scipy.io.loadmat(file)
X_train = data['Xtest']

# Display basic information about the data
print(f"Data shape: {X_train.shape}")
print(f"Data type: {X_train.dtype}")
print(f"Min value: {np.min(X_train)}")
print(f"Max value: {np.max(X_train)}")

# plot the data
plt.plot(X_train)
plt.show()
# Out:
# Data shape: (1000, 1)
# Data type: uint8
# Min value: 2
# Max value: 255
# Data shape: (200, 1)
# Data type: uint8
# Min value: 3
# Max value: 255

# %% [markdown]
# Now, we scale the data, because then the network works better and faster.
# I also want to scale it back, so that it can get the right outputs.

# %%
import sklearn
from sklearn.preprocessing import StandardScaler

#let's scale the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(X_train.reshape(-1, 1))

#We also want the scaled back data ready:
restored_data = scaler.inverse_transform(scaled_data)

# Printing the first few values of the scaled and restored data to check
print(f"First few scaled values:\n{scaled_data[:5]}")
print(f"First few restored values:\n{restored_data[:5]}")

#Display basic information about the data
print(f"Data shape: {scaled_data.shape}")
print(f"Data type: {scaled_data.dtype}")
print(f"Min value: {np.min(scaled_data)}")
print(f"Max value: {np.max(scaled_data)}")
# Out:
# First few scaled values:
# [[ 0.55720154]
#  [ 1.73111118]
#  [ 0.74929585]
#  [-0.40326998]
#  [-0.8088024 ]]
# First few restored values:
# [[ 86.]
#  [141.]
#  [ 95.]
#  [ 41.]
#  [ 22.]]
# Data shape: (1000, 1)
# Data type: float64
# Min value: -1.2356786270219065
# Max value: 4.16430570013708

# %%
from torch.utils.data import TensorDataset, DataLoader
#Now we want to create sequences from our data, then split into training, validation, and test sets
seq_len = 30

#Define the function that retrieves the sequences:
def create_sequences(data, seq_len):
    sequences = []
    labels = []
    for i in range(len(data) - seq_len):
        seq = data[i:i+seq_len]
        label = data[i+seq_len]
        sequences.append(seq)
        labels.append(label)
    return np.array(sequences), np.array(labels)

# Define the split point for test data - we'll use the last portion for testing
test_ratio = 0.20 # might need to have this overlap with the validation set
val_ratio = 0.1
train_ratio = 0.70

# Calculate sizes
total_size = len(scaled_data)
test_size = int(test_ratio * total_size)
val_size = int(val_ratio * (total_size - test_size))
train_size = total_size - test_size - val_size

# Split the data before creating sequences
train_val_data = scaled_data[:-test_size]
test_data = scaled_data[-test_size:]

# Create sequences only for training and validation data
X_sequences, y_labels = create_sequences(train_val_data, seq_len)

# Convert to PyTorch tensors
X_sequences = torch.tensor(X_sequences, dtype=torch.float32)
y_labels = torch.tensor(y_labels, dtype=torch.float32)

# Create a TensorDataset
dataset = TensorDataset(X_sequences, y_labels)

# Calculate sizes for train and validation
dataset_size = len(dataset)
train_size = int(train_ratio / (train_ratio + val_ratio) * dataset_size)
val_size = dataset_size - train_size

# Split the dataset for train and validation
train_dataset, val_dataset = torch.utils.data.random_split(
    dataset, [train_size, val_size],
    generator=torch.Generator().manual_seed(42)
)

# Create DataLoaders for training and validation
batch_size = 512
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# We keep test_data as is (not split into sequences) for autoregressive prediction

# Print information about the splits
print(f"Total data points: {total_size}")
print(f"Training sequences: {train_size}")
print(f"Validation sequences: {val_size}")
print(f"Test data points: {len(test_data)}")
# Out:
# Total data points: 1000
# Training sequences: 673
# Validation sequences: 97
# Test data points: 200

# %%
#making the LSTM
class LSTMModel(nn.Module):
    def __init__(self, input_size=1, hidden_size=64, num_layers=1, dropout=0.2):
        super().__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout if num_layers > 1 else 0)
        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
        out, _ = self.lstm(x)
        out = out[:, -1, :]  # use output from last time step
        out = self.fc(out)
        return out

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = LSTMModel(hidden_size=64, num_layers=1, dropout=0.0).to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

# training loop with early stopping
num_epochs = 1000
train_losses, val_losses = [], []
best_val_loss = float('inf')
best_model_state = None
best_epoch = -1
patience = 20  # number of epochs to wait for improvement
counter = 0  # counter for patience

for epoch in range(num_epochs):
    # train
    model.train()
    train_loss = 0
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        optimizer.zero_grad()
        output = model(X_batch)
        loss = criterion(output.squeeze(), y_batch.squeeze())
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    
    # validation loop
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for X_batch, y_batch in val_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            output = model(X_batch)
            loss = criterion(output.squeeze(), y_batch.squeeze())
            val_loss += loss.item()
    
    # record losses
    train_loss /= len(train_loader)
    val_loss /= len(val_loader)
    train_losses.append(train_loss)
    val_losses.append(val_loss)
    
    # save the best model and check for early stopping
    if val_loss < best_val_loss:
        best_epoch = epoch
        best_val_loss = val_loss
        best_model_state = model.state_dict().copy()
        counter = 0  # reset counter
        print(f"Epoch {epoch+1}/{num_epochs} - Train Loss: {train_loss:.4f} - Val Loss: {val_loss:.4f} (Best Model Saved)")
    else:
        counter += 1  # increment counter
        print(f"Epoch {epoch+1}/{num_epochs} - Train Loss: {train_loss:.4f} - Val Loss: {val_loss:.4f}")
        
    # early stopping check
    if counter >= patience:
        print(f"Early stopping triggered after {epoch+1} epochs")
        break

# load best model
model.load_state_dict(best_model_state)
print(f"Best validation loss: {best_val_loss:.4f} for epoch {best_epoch}")

## plot losses
plt.figure(figsize=(10, 6))
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.show()




# %%
# autoregressive prediction on the test set
model.eval()
predictions = []
initial_sequence_np = test_data[:seq_len].reshape(1, seq_len, 1)
current_sequence = torch.tensor(initial_sequence_np, dtype=torch.float32).to(device)

num_predictions = len(test_data) - seq_len

with torch.no_grad():
    for _ in range(num_predictions):
        prediction = model(current_sequence)
        predictions.append(prediction.item())
        # append the prediction and remove the oldest point
        new_point = prediction.reshape(1, 1, 1)
        current_sequence = torch.cat((current_sequence[:, 1:, :], new_point), dim=1)

# inverse transform predictions and actual test data
predicted_values = scaler.inverse_transform(np.array(predictions).reshape(-1, 1))
actual_values = scaler.inverse_transform(test_data[seq_len:]) # compare against the part of test_data we predicted

# calculate mae and mse
from sklearn.metrics import mean_absolute_error, mean_squared_error

mae = mean_absolute_error(actual_values, predicted_values)
mse = mean_squared_error(actual_values, predicted_values)

print(f"Test MAE: {mae:.4f}")
print(f"Test MSE: {mse:.4f}")

# plot predictions vs actual
plt.figure(figsize=(12, 6))
plt.plot(actual_values, label='Actual Values', marker='.')
plt.plot(predicted_values, label='Predicted Values', marker='x')
plt.title('Autoregressive Prediction vs Actual Test Data')
plt.xlabel('Time Step (after initial sequence)')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/1000 - Train Loss: 1.0774 - Val Loss: 1.2260 (Best Model Saved)
# Epoch 2/1000 - Train Loss: 0.9243 - Val Loss: 1.2251 (Best Model Saved)
# Epoch 3/1000 - Train Loss: 1.0570 - Val Loss: 1.2243 (Best Model Saved)
# Epoch 4/1000 - Train Loss: 0.9940 - Val Loss: 1.2234 (Best Model Saved)
# Epoch 5/1000 - Train Loss: 1.0629 - Val Loss: 1.2225 (Best Model Saved)
# Epoch 6/1000 - Train Loss: 1.0507 - Val Loss: 1.2216 (Best Model Saved)
# Epoch 7/1000 - Train Loss: 0.9112 - Val Loss: 1.2207 (Best Model Saved)
# Epoch 8/1000 - Train Loss: 1.0270 - Val Loss: 1.2198 (Best Model Saved)
# Epoch 9/1000 - Train Loss: 0.9890 - Val Loss: 1.2189 (Best Model Saved)
# Epoch 10/1000 - Train Loss: 1.0502 - Val Loss: 1.2179 (Best Model Saved)
# Epoch 11/1000 - Train Loss: 0.9502 - Val Loss: 1.2170 (Best Model Saved)
# Epoch 12/1000 - Train Loss: 0.9813 - Val Loss: 1.2161 (Best Model Saved)
# Epoch 13/1000 - Train Loss: 1.0005 - Val Loss: 1.2151 (Best Model Saved)
# Epoch 14/1000 - Train Loss: 1.0168 - Val Loss: 1.2142 (Best Model Saved)
# Epoch 15/1000 - Train Loss: 1.0249 - Val Loss: 1.2132 (Best Model Saved)
# Epoch 16/1000 - Train Loss: 0.9983 - Val Loss: 1.2123 (Best Model Saved)
# Epoch 17/1000 - Train Loss: 0.9730 - Val Loss: 1.2113 (Best Model Saved)
# Epoch 18/1000 - Train Loss: 1.0413 - Val Loss: 1.2103 (Best Model Saved)
# Epoch 19/1000 - Train Loss: 0.9496 - Val Loss: 1.2094 (Best Model Saved)
# Epoch 20/1000 - Train Loss: 0.9838 - Val Loss: 1.2084 (Best Model Saved)
# Epoch 21/1000 - Train Loss: 1.0030 - Val Loss: 1.2074 (Best Model Saved)
# Epoch 22/1000 - Train Loss: 1.0293 - Val Loss: 1.2064 (Best Model Saved)
# Epoch 23/1000 - Train Loss: 0.9505 - Val Loss: 1.2054 (Best Model Saved)
# Epoch 24/1000 - Train Loss: 1.0330 - Val Loss: 1.2044 (Best Model Saved)
# Epoch 25/1000 - Train Loss: 0.9914 - Val Loss: 1.2033 (Best Model Saved)
# Epoch 26/1000 - Train Loss: 1.0158 - Val Loss: 1.2023 (Best Model Saved)
# Epoch 27/1000 - Train Loss: 0.9919 - Val Loss: 1.2012 (Best Model Saved)
# Epoch 28/1000 - Train Loss: 0.9778 - Val Loss: 1.2001 (Best Model Saved)
# Epoch 29/1000 - Train Loss: 0.9962 - Val Loss: 1.1990 (Best Model Saved)
# Epoch 30/1000 - Train Loss: 0.9806 - Val Loss: 1.1980 (Best Model Saved)
# Epoch 31/1000 - Train Loss: 0.9380 - Val Loss: 1.1969 (Best Model Saved)
# Epoch 32/1000 - Train Loss: 1.0109 - Val Loss: 1.1958 (Best Model Saved)
# Epoch 33/1000 - Train Loss: 0.9882 - Val Loss: 1.1947 (Best Model Saved)
# Epoch 34/1000 - Train Loss: 0.9844 - Val Loss: 1.1936 (Best Model Saved)
# Epoch 35/1000 - Train Loss: 0.9403 - Val Loss: 1.1924 (Best Model Saved)
# Epoch 36/1000 - Train Loss: 1.0412 - Val Loss: 1.1913 (Best Model Saved)
# Epoch 37/1000 - Train Loss: 0.9493 - Val Loss: 1.1901 (Best Model Saved)
# Epoch 38/1000 - Train Loss: 0.9452 - Val Loss: 1.1889 (Best Model Saved)
# Epoch 39/1000 - Train Loss: 0.9962 - Val Loss: 1.1878 (Best Model Saved)
# Epoch 40/1000 - Train Loss: 0.9207 - Val Loss: 1.1866 (Best Model Saved)
# Epoch 41/1000 - Train Loss: 0.9586 - Val Loss: 1.1854 (Best Model Saved)
# Epoch 42/1000 - Train Loss: 1.0080 - Val Loss: 1.1841 (Best Model Saved)
# Epoch 43/1000 - Train Loss: 0.8978 - Val Loss: 1.1829 (Best Model Saved)
# Epoch 44/1000 - Train Loss: 0.9435 - Val Loss: 1.1816 (Best Model Saved)
# Epoch 45/1000 - Train Loss: 0.9021 - Val Loss: 1.1803 (Best Model Saved)
# Epoch 46/1000 - Train Loss: 0.9891 - Val Loss: 1.1790 (Best Model Saved)
# Epoch 47/1000 - Train Loss: 0.8992 - Val Loss: 1.1777 (Best Model Saved)
# Epoch 48/1000 - Train Loss: 0.9396 - Val Loss: 1.1764 (Best Model Saved)
# Epoch 49/1000 - Train Loss: 0.9423 - Val Loss: 1.1751 (Best Model Saved)
# Epoch 50/1000 - Train Loss: 1.0105 - Val Loss: 1.1737 (Best Model Saved)
# Epoch 51/1000 - Train Loss: 0.9915 - Val Loss: 1.1723 (Best Model Saved)
# Epoch 52/1000 - Train Loss: 0.9270 - Val Loss: 1.1708 (Best Model Saved)
# Epoch 53/1000 - Train Loss: 1.0144 - Val Loss: 1.1693 (Best Model Saved)
# Epoch 54/1000 - Train Loss: 1.0156 - Val Loss: 1.1677 (Best Model Saved)
# Epoch 55/1000 - Train Loss: 0.9637 - Val Loss: 1.1661 (Best Model Saved)
# Epoch 56/1000 - Train Loss: 0.9429 - Val Loss: 1.1645 (Best Model Saved)
# Epoch 57/1000 - Train Loss: 0.9489 - Val Loss: 1.1628 (Best Model Saved)
# Epoch 58/1000 - Train Loss: 0.8557 - Val Loss: 1.1612 (Best Model Saved)
# Epoch 59/1000 - Train Loss: 1.0018 - Val Loss: 1.1596 (Best Model Saved)
# Epoch 60/1000 - Train Loss: 0.8716 - Val Loss: 1.1579 (Best Model Saved)
# Epoch 61/1000 - Train Loss: 0.9317 - Val Loss: 1.1563 (Best Model Saved)
# Epoch 62/1000 - Train Loss: 0.9710 - Val Loss: 1.1545 (Best Model Saved)
# Epoch 63/1000 - Train Loss: 0.9992 - Val Loss: 1.1528 (Best Model Saved)
# Epoch 64/1000 - Train Loss: 0.9257 - Val Loss: 1.1510 (Best Model Saved)
# Epoch 65/1000 - Train Loss: 0.9376 - Val Loss: 1.1491 (Best Model Saved)
# Epoch 66/1000 - Train Loss: 0.9621 - Val Loss: 1.1472 (Best Model Saved)
# Epoch 67/1000 - Train Loss: 0.8915 - Val Loss: 1.1452 (Best Model Saved)
# Epoch 68/1000 - Train Loss: 0.9224 - Val Loss: 1.1432 (Best Model Saved)
# Epoch 69/1000 - Train Loss: 0.8966 - Val Loss: 1.1412 (Best Model Saved)
# Epoch 70/1000 - Train Loss: 0.9730 - Val Loss: 1.1392 (Best Model Saved)
# Epoch 71/1000 - Train Loss: 0.8891 - Val Loss: 1.1371 (Best Model Saved)
# Epoch 72/1000 - Train Loss: 0.9269 - Val Loss: 1.1349 (Best Model Saved)
# Epoch 73/1000 - Train Loss: 0.9026 - Val Loss: 1.1327 (Best Model Saved)
# Epoch 74/1000 - Train Loss: 0.9826 - Val Loss: 1.1304 (Best Model Saved)
# Epoch 75/1000 - Train Loss: 0.9262 - Val Loss: 1.1280 (Best Model Saved)
# Epoch 76/1000 - Train Loss: 0.9668 - Val Loss: 1.1255 (Best Model Saved)
# Epoch 77/1000 - Train Loss: 0.9709 - Val Loss: 1.1230 (Best Model Saved)
# Epoch 78/1000 - Train Loss: 0.8967 - Val Loss: 1.1204 (Best Model Saved)
# Epoch 79/1000 - Train Loss: 0.9676 - Val Loss: 1.1178 (Best Model Saved)
# Epoch 80/1000 - Train Loss: 0.9584 - Val Loss: 1.1151 (Best Model Saved)
# Epoch 81/1000 - Train Loss: 0.9282 - Val Loss: 1.1123 (Best Model Saved)
# Epoch 82/1000 - Train Loss: 0.9628 - Val Loss: 1.1095 (Best Model Saved)
# Epoch 83/1000 - Train Loss: 0.8958 - Val Loss: 1.1065 (Best Model Saved)
# Epoch 84/1000 - Train Loss: 0.8964 - Val Loss: 1.1036 (Best Model Saved)
# Epoch 85/1000 - Train Loss: 0.9603 - Val Loss: 1.1005 (Best Model Saved)
# Epoch 86/1000 - Train Loss: 0.8722 - Val Loss: 1.0974 (Best Model Saved)
# Epoch 87/1000 - Train Loss: 0.8826 - Val Loss: 1.0943 (Best Model Saved)
# Epoch 88/1000 - Train Loss: 0.9654 - Val Loss: 1.0910 (Best Model Saved)
# Epoch 89/1000 - Train Loss: 0.9353 - Val Loss: 1.0876 (Best Model Saved)
# Epoch 90/1000 - Train Loss: 0.8686 - Val Loss: 1.0841 (Best Model Saved)
# Epoch 91/1000 - Train Loss: 0.8952 - Val Loss: 1.0806 (Best Model Saved)
# Epoch 92/1000 - Train Loss: 0.9158 - Val Loss: 1.0769 (Best Model Saved)
# Epoch 93/1000 - Train Loss: 0.9354 - Val Loss: 1.0731 (Best Model Saved)
# Epoch 94/1000 - Train Loss: 0.8692 - Val Loss: 1.0692 (Best Model Saved)
# Epoch 95/1000 - Train Loss: 0.8878 - Val Loss: 1.0651 (Best Model Saved)
# Epoch 96/1000 - Train Loss: 0.8600 - Val Loss: 1.0609 (Best Model Saved)
# Epoch 97/1000 - Train Loss: 0.9132 - Val Loss: 1.0566 (Best Model Saved)
# Epoch 98/1000 - Train Loss: 0.8451 - Val Loss: 1.0521 (Best Model Saved)
# Epoch 99/1000 - Train Loss: 0.8478 - Val Loss: 1.0475 (Best Model Saved)
# Epoch 100/1000 - Train Loss: 0.8454 - Val Loss: 1.0427 (Best Model Saved)
# Epoch 101/1000 - Train Loss: 0.8727 - Val Loss: 1.0378 (Best Model Saved)
# Epoch 102/1000 - Train Loss: 0.8930 - Val Loss: 1.0327 (Best Model Saved)
# Epoch 103/1000 - Train Loss: 0.8957 - Val Loss: 1.0274 (Best Model Saved)
# Epoch 104/1000 - Train Loss: 0.8544 - Val Loss: 1.0219 (Best Model Saved)
# Epoch 105/1000 - Train Loss: 0.7974 - Val Loss: 1.0162 (Best Model Saved)
# Epoch 106/1000 - Train Loss: 0.7976 - Val Loss: 1.0103 (Best Model Saved)
# Epoch 107/1000 - Train Loss: 0.8309 - Val Loss: 1.0043 (Best Model Saved)
# Epoch 108/1000 - Train Loss: 0.8172 - Val Loss: 0.9980 (Best Model Saved)
# Epoch 109/1000 - Train Loss: 0.8331 - Val Loss: 0.9915 (Best Model Saved)
# Epoch 110/1000 - Train Loss: 0.8565 - Val Loss: 0.9846 (Best Model Saved)
# Epoch 111/1000 - Train Loss: 0.8646 - Val Loss: 0.9773 (Best Model Saved)
# Epoch 112/1000 - Train Loss: 0.8256 - Val Loss: 0.9696 (Best Model Saved)
# Epoch 113/1000 - Train Loss: 0.7598 - Val Loss: 0.9616 (Best Model Saved)
# Epoch 114/1000 - Train Loss: 0.8627 - Val Loss: 0.9533 (Best Model Saved)
# Epoch 115/1000 - Train Loss: 0.7913 - Val Loss: 0.9446 (Best Model Saved)
# Epoch 116/1000 - Train Loss: 0.7718 - Val Loss: 0.9354 (Best Model Saved)
# Epoch 117/1000 - Train Loss: 0.8023 - Val Loss: 0.9259 (Best Model Saved)
# Epoch 118/1000 - Train Loss: 0.7610 - Val Loss: 0.9159 (Best Model Saved)
# Epoch 119/1000 - Train Loss: 0.7139 - Val Loss: 0.9053 (Best Model Saved)
# Epoch 120/1000 - Train Loss: 0.7548 - Val Loss: 0.8944 (Best Model Saved)
# Epoch 121/1000 - Train Loss: 0.7343 - Val Loss: 0.8828 (Best Model Saved)
# Epoch 122/1000 - Train Loss: 0.7112 - Val Loss: 0.8706 (Best Model Saved)
# Epoch 123/1000 - Train Loss: 0.7525 - Val Loss: 0.8578 (Best Model Saved)
# Epoch 124/1000 - Train Loss: 0.6882 - Val Loss: 0.8442 (Best Model Saved)
# Epoch 125/1000 - Train Loss: 0.7803 - Val Loss: 0.8298 (Best Model Saved)
# Epoch 126/1000 - Train Loss: 0.6894 - Val Loss: 0.8143 (Best Model Saved)
# Epoch 127/1000 - Train Loss: 0.6435 - Val Loss: 0.7977 (Best Model Saved)
# Epoch 128/1000 - Train Loss: 0.6288 - Val Loss: 0.7802 (Best Model Saved)
# Epoch 129/1000 - Train Loss: 0.6828 - Val Loss: 0.7615 (Best Model Saved)
# Epoch 130/1000 - Train Loss: 0.5919 - Val Loss: 0.7414 (Best Model Saved)
# Epoch 131/1000 - Train Loss: 0.5763 - Val Loss: 0.7202 (Best Model Saved)
# Epoch 132/1000 - Train Loss: 0.6284 - Val Loss: 0.6976 (Best Model Saved)
# Epoch 133/1000 - Train Loss: 0.5891 - Val Loss: 0.6731 (Best Model Saved)
# Epoch 134/1000 - Train Loss: 0.5543 - Val Loss: 0.6470 (Best Model Saved)
# Epoch 135/1000 - Train Loss: 0.5557 - Val Loss: 0.6193 (Best Model Saved)
# Epoch 136/1000 - Train Loss: 0.4742 - Val Loss: 0.5906 (Best Model Saved)
# Epoch 137/1000 - Train Loss: 0.5285 - Val Loss: 0.5612 (Best Model Saved)
# Epoch 138/1000 - Train Loss: 0.4731 - Val Loss: 0.5309 (Best Model Saved)
# Epoch 139/1000 - Train Loss: 0.4397 - Val Loss: 0.5008 (Best Model Saved)
# Epoch 140/1000 - Train Loss: 0.4764 - Val Loss: 0.4721 (Best Model Saved)
# Epoch 141/1000 - Train Loss: 0.4177 - Val Loss: 0.4450 (Best Model Saved)
# Epoch 142/1000 - Train Loss: 0.4348 - Val Loss: 0.4203 (Best Model Saved)
# Epoch 143/1000 - Train Loss: 0.3942 - Val Loss: 0.3981 (Best Model Saved)
# Epoch 144/1000 - Train Loss: 0.4006 - Val Loss: 0.3783 (Best Model Saved)
# Epoch 145/1000 - Train Loss: 0.3639 - Val Loss: 0.3617 (Best Model Saved)
# Epoch 146/1000 - Train Loss: 0.3338 - Val Loss: 0.3494 (Best Model Saved)
# Epoch 147/1000 - Train Loss: 0.3538 - Val Loss: 0.3412 (Best Model Saved)
# Epoch 148/1000 - Train Loss: 0.3244 - Val Loss: 0.3359 (Best Model Saved)
# Epoch 149/1000 - Train Loss: 0.3266 - Val Loss: 0.3329 (Best Model Saved)
# Epoch 150/1000 - Train Loss: 0.3273 - Val Loss: 0.3312 (Best Model Saved)
# Epoch 151/1000 - Train Loss: 0.2779 - Val Loss: 0.3304 (Best Model Saved)
# Epoch 152/1000 - Train Loss: 0.3043 - Val Loss: 0.3291 (Best Model Saved)
# Epoch 153/1000 - Train Loss: 0.3250 - Val Loss: 0.3272 (Best Model Saved)
# Epoch 154/1000 - Train Loss: 0.3525 - Val Loss: 0.3248 (Best Model Saved)
# Epoch 155/1000 - Train Loss: 0.2898 - Val Loss: 0.3210 (Best Model Saved)
# Epoch 156/1000 - Train Loss: 0.3220 - Val Loss: 0.3168 (Best Model Saved)
# Epoch 157/1000 - Train Loss: 0.2757 - Val Loss: 0.3124 (Best Model Saved)
# Epoch 158/1000 - Train Loss: 0.2949 - Val Loss: 0.3082 (Best Model Saved)
# Epoch 159/1000 - Train Loss: 0.3076 - Val Loss: 0.3041 (Best Model Saved)
# Epoch 160/1000 - Train Loss: 0.2935 - Val Loss: 0.3007 (Best Model Saved)
# Epoch 161/1000 - Train Loss: 0.2914 - Val Loss: 0.2983 (Best Model Saved)
# Epoch 162/1000 - Train Loss: 0.3101 - Val Loss: 0.2958 (Best Model Saved)
# Epoch 163/1000 - Train Loss: 0.3147 - Val Loss: 0.2929 (Best Model Saved)
# Epoch 164/1000 - Train Loss: 0.2826 - Val Loss: 0.2903 (Best Model Saved)
# Epoch 165/1000 - Train Loss: 0.3007 - Val Loss: 0.2878 (Best Model Saved)
# Epoch 166/1000 - Train Loss: 0.2753 - Val Loss: 0.2851 (Best Model Saved)
# Epoch 167/1000 - Train Loss: 0.2567 - Val Loss: 0.2825 (Best Model Saved)
# Epoch 168/1000 - Train Loss: 0.2817 - Val Loss: 0.2795 (Best Model Saved)
# Epoch 169/1000 - Train Loss: 0.2938 - Val Loss: 0.2764 (Best Model Saved)
# Epoch 170/1000 - Train Loss: 0.3050 - Val Loss: 0.2737 (Best Model Saved)
# Epoch 171/1000 - Train Loss: 0.2711 - Val Loss: 0.2714 (Best Model Saved)
# Epoch 172/1000 - Train Loss: 0.2668 - Val Loss: 0.2687 (Best Model Saved)
# Epoch 173/1000 - Train Loss: 0.2680 - Val Loss: 0.2666 (Best Model Saved)
# Epoch 174/1000 - Train Loss: 0.3203 - Val Loss: 0.2652 (Best Model Saved)
# Epoch 175/1000 - Train Loss: 0.2668 - Val Loss: 0.2636 (Best Model Saved)
# Epoch 176/1000 - Train Loss: 0.2278 - Val Loss: 0.2615 (Best Model Saved)
# Epoch 177/1000 - Train Loss: 0.2277 - Val Loss: 0.2591 (Best Model Saved)
# Epoch 178/1000 - Train Loss: 0.2436 - Val Loss: 0.2563 (Best Model Saved)
# Epoch 179/1000 - Train Loss: 0.2667 - Val Loss: 0.2535 (Best Model Saved)
# Epoch 180/1000 - Train Loss: 0.2722 - Val Loss: 0.2509 (Best Model Saved)
# Epoch 181/1000 - Train Loss: 0.2592 - Val Loss: 0.2484 (Best Model Saved)
# Epoch 182/1000 - Train Loss: 0.2305 - Val Loss: 0.2464 (Best Model Saved)
# Epoch 183/1000 - Train Loss: 0.2562 - Val Loss: 0.2441 (Best Model Saved)
# Epoch 184/1000 - Train Loss: 0.2480 - Val Loss: 0.2410 (Best Model Saved)
# Epoch 185/1000 - Train Loss: 0.2230 - Val Loss: 0.2377 (Best Model Saved)
# Epoch 186/1000 - Train Loss: 0.2220 - Val Loss: 0.2346 (Best Model Saved)
# Epoch 187/1000 - Train Loss: 0.2591 - Val Loss: 0.2316 (Best Model Saved)
# Epoch 188/1000 - Train Loss: 0.2554 - Val Loss: 0.2292 (Best Model Saved)
# Epoch 189/1000 - Train Loss: 0.2544 - Val Loss: 0.2271 (Best Model Saved)
# Epoch 190/1000 - Train Loss: 0.2388 - Val Loss: 0.2246 (Best Model Saved)
# Epoch 191/1000 - Train Loss: 0.2733 - Val Loss: 0.2223 (Best Model Saved)
# Epoch 192/1000 - Train Loss: 0.2561 - Val Loss: 0.2204 (Best Model Saved)
# Epoch 193/1000 - Train Loss: 0.2302 - Val Loss: 0.2186 (Best Model Saved)
# Epoch 194/1000 - Train Loss: 0.2213 - Val Loss: 0.2168 (Best Model Saved)
# Epoch 195/1000 - Train Loss: 0.2250 - Val Loss: 0.2151 (Best Model Saved)
# Epoch 196/1000 - Train Loss: 0.2481 - Val Loss: 0.2134 (Best Model Saved)
# Epoch 197/1000 - Train Loss: 0.2332 - Val Loss: 0.2118 (Best Model Saved)
# Epoch 198/1000 - Train Loss: 0.2310 - Val Loss: 0.2104 (Best Model Saved)
# Epoch 199/1000 - Train Loss: 0.2091 - Val Loss: 0.2090 (Best Model Saved)
# Epoch 200/1000 - Train Loss: 0.2842 - Val Loss: 0.2073 (Best Model Saved)
# Epoch 201/1000 - Train Loss: 0.2652 - Val Loss: 0.2051 (Best Model Saved)
# Epoch 202/1000 - Train Loss: 0.2159 - Val Loss: 0.2030 (Best Model Saved)
# Epoch 203/1000 - Train Loss: 0.2087 - Val Loss: 0.2014 (Best Model Saved)
# Epoch 204/1000 - Train Loss: 0.2548 - Val Loss: 0.1996 (Best Model Saved)
# Epoch 205/1000 - Train Loss: 0.2300 - Val Loss: 0.1970 (Best Model Saved)
# Epoch 206/1000 - Train Loss: 0.1981 - Val Loss: 0.1944 (Best Model Saved)
# Epoch 207/1000 - Train Loss: 0.2142 - Val Loss: 0.1927 (Best Model Saved)
# Epoch 208/1000 - Train Loss: 0.2144 - Val Loss: 0.1915 (Best Model Saved)
# Epoch 209/1000 - Train Loss: 0.1987 - Val Loss: 0.1903 (Best Model Saved)
# Epoch 210/1000 - Train Loss: 0.2116 - Val Loss: 0.1890 (Best Model Saved)
# Epoch 211/1000 - Train Loss: 0.1921 - Val Loss: 0.1880 (Best Model Saved)
# Epoch 212/1000 - Train Loss: 0.2421 - Val Loss: 0.1879 (Best Model Saved)
# Epoch 213/1000 - Train Loss: 0.2156 - Val Loss: 0.1873 (Best Model Saved)
# Epoch 214/1000 - Train Loss: 0.2116 - Val Loss: 0.1852 (Best Model Saved)
# Epoch 215/1000 - Train Loss: 0.2185 - Val Loss: 0.1826 (Best Model Saved)
# Epoch 216/1000 - Train Loss: 0.1891 - Val Loss: 0.1811 (Best Model Saved)
# Epoch 217/1000 - Train Loss: 0.2161 - Val Loss: 0.1790 (Best Model Saved)
# Epoch 218/1000 - Train Loss: 0.1840 - Val Loss: 0.1764 (Best Model Saved)
# Epoch 219/1000 - Train Loss: 0.2115 - Val Loss: 0.1745 (Best Model Saved)
# Epoch 220/1000 - Train Loss: 0.2000 - Val Loss: 0.1727 (Best Model Saved)
# Epoch 221/1000 - Train Loss: 0.2224 - Val Loss: 0.1705 (Best Model Saved)
# Epoch 222/1000 - Train Loss: 0.1992 - Val Loss: 0.1681 (Best Model Saved)
# Epoch 223/1000 - Train Loss: 0.1863 - Val Loss: 0.1659 (Best Model Saved)
# Epoch 224/1000 - Train Loss: 0.2152 - Val Loss: 0.1640 (Best Model Saved)
# Epoch 225/1000 - Train Loss: 0.1892 - Val Loss: 0.1624 (Best Model Saved)
# Epoch 226/1000 - Train Loss: 0.1958 - Val Loss: 0.1611 (Best Model Saved)
# Epoch 227/1000 - Train Loss: 0.1826 - Val Loss: 0.1603 (Best Model Saved)
# Epoch 228/1000 - Train Loss: 0.2055 - Val Loss: 0.1595 (Best Model Saved)
# Epoch 229/1000 - Train Loss: 0.1984 - Val Loss: 0.1581 (Best Model Saved)
# Epoch 230/1000 - Train Loss: 0.1868 - Val Loss: 0.1564 (Best Model Saved)
# Epoch 231/1000 - Train Loss: 0.1661 - Val Loss: 0.1547 (Best Model Saved)
# Epoch 232/1000 - Train Loss: 0.1924 - Val Loss: 0.1530 (Best Model Saved)
# Epoch 233/1000 - Train Loss: 0.1593 - Val Loss: 0.1511 (Best Model Saved)
# Epoch 234/1000 - Train Loss: 0.1844 - Val Loss: 0.1496 (Best Model Saved)
# Epoch 235/1000 - Train Loss: 0.2033 - Val Loss: 0.1487 (Best Model Saved)
# Epoch 236/1000 - Train Loss: 0.1735 - Val Loss: 0.1475 (Best Model Saved)
# Epoch 237/1000 - Train Loss: 0.1721 - Val Loss: 0.1452 (Best Model Saved)
# Epoch 238/1000 - Train Loss: 0.2211 - Val Loss: 0.1435 (Best Model Saved)
# Epoch 239/1000 - Train Loss: 0.1526 - Val Loss: 0.1426 (Best Model Saved)
# Epoch 240/1000 - Train Loss: 0.1658 - Val Loss: 0.1420 (Best Model Saved)
# Epoch 241/1000 - Train Loss: 0.1935 - Val Loss: 0.1415 (Best Model Saved)
# Epoch 242/1000 - Train Loss: 0.1800 - Val Loss: 0.1409 (Best Model Saved)
# Epoch 243/1000 - Train Loss: 0.1496 - Val Loss: 0.1401 (Best Model Saved)
# Epoch 244/1000 - Train Loss: 0.1687 - Val Loss: 0.1389 (Best Model Saved)
# Epoch 245/1000 - Train Loss: 0.1582 - Val Loss: 0.1376 (Best Model Saved)
# Epoch 246/1000 - Train Loss: 0.1727 - Val Loss: 0.1361 (Best Model Saved)
# Epoch 247/1000 - Train Loss: 0.1684 - Val Loss: 0.1348 (Best Model Saved)
# Epoch 248/1000 - Train Loss: 0.1492 - Val Loss: 0.1335 (Best Model Saved)
# Epoch 249/1000 - Train Loss: 0.1529 - Val Loss: 0.1323 (Best Model Saved)
# Epoch 250/1000 - Train Loss: 0.1704 - Val Loss: 0.1309 (Best Model Saved)
# Epoch 251/1000 - Train Loss: 0.1721 - Val Loss: 0.1294 (Best Model Saved)
# Epoch 252/1000 - Train Loss: 0.1566 - Val Loss: 0.1285 (Best Model Saved)
# Epoch 253/1000 - Train Loss: 0.1587 - Val Loss: 0.1279 (Best Model Saved)
# Epoch 254/1000 - Train Loss: 0.1828 - Val Loss: 0.1270 (Best Model Saved)
# Epoch 255/1000 - Train Loss: 0.1650 - Val Loss: 0.1266 (Best Model Saved)
# Epoch 256/1000 - Train Loss: 0.1729 - Val Loss: 0.1257 (Best Model Saved)
# Epoch 257/1000 - Train Loss: 0.1430 - Val Loss: 0.1247 (Best Model Saved)
# Epoch 258/1000 - Train Loss: 0.1728 - Val Loss: 0.1242 (Best Model Saved)
# Epoch 259/1000 - Train Loss: 0.1417 - Val Loss: 0.1230 (Best Model Saved)
# Epoch 260/1000 - Train Loss: 0.1833 - Val Loss: 0.1219 (Best Model Saved)
# Epoch 261/1000 - Train Loss: 0.1614 - Val Loss: 0.1229
# Epoch 262/1000 - Train Loss: 0.1865 - Val Loss: 0.1221
# Epoch 263/1000 - Train Loss: 0.1743 - Val Loss: 0.1189 (Best Model Saved)
# Epoch 264/1000 - Train Loss: 0.1473 - Val Loss: 0.1167 (Best Model Saved)
# Epoch 265/1000 - Train Loss: 0.1715 - Val Loss: 0.1158 (Best Model Saved)
# Epoch 266/1000 - Train Loss: 0.1253 - Val Loss: 0.1149 (Best Model Saved)
# Epoch 267/1000 - Train Loss: 0.1534 - Val Loss: 0.1140 (Best Model Saved)
# Epoch 268/1000 - Train Loss: 0.1492 - Val Loss: 0.1135 (Best Model Saved)
# Epoch 269/1000 - Train Loss: 0.1394 - Val Loss: 0.1126 (Best Model Saved)
# Epoch 270/1000 - Train Loss: 0.1638 - Val Loss: 0.1109 (Best Model Saved)
# Epoch 271/1000 - Train Loss: 0.1574 - Val Loss: 0.1094 (Best Model Saved)
# Epoch 272/1000 - Train Loss: 0.1603 - Val Loss: 0.1085 (Best Model Saved)
# Epoch 273/1000 - Train Loss: 0.1255 - Val Loss: 0.1082 (Best Model Saved)
# Epoch 274/1000 - Train Loss: 0.1514 - Val Loss: 0.1079 (Best Model Saved)
# Epoch 275/1000 - Train Loss: 0.1542 - Val Loss: 0.1068 (Best Model Saved)
# Epoch 276/1000 - Train Loss: 0.1410 - Val Loss: 0.1064 (Best Model Saved)
# Epoch 277/1000 - Train Loss: 0.1282 - Val Loss: 0.1064 (Best Model Saved)
# Epoch 278/1000 - Train Loss: 0.1400 - Val Loss: 0.1056 (Best Model Saved)
# Epoch 279/1000 - Train Loss: 0.2051 - Val Loss: 0.1048 (Best Model Saved)
# Epoch 280/1000 - Train Loss: 0.1235 - Val Loss: 0.1044 (Best Model Saved)
# Epoch 281/1000 - Train Loss: 0.1593 - Val Loss: 0.1030 (Best Model Saved)
# Epoch 282/1000 - Train Loss: 0.1328 - Val Loss: 0.1020 (Best Model Saved)
# Epoch 283/1000 - Train Loss: 0.1130 - Val Loss: 0.1015 (Best Model Saved)
# Epoch 284/1000 - Train Loss: 0.1355 - Val Loss: 0.1009 (Best Model Saved)
# Epoch 285/1000 - Train Loss: 0.1471 - Val Loss: 0.1002 (Best Model Saved)
# Epoch 286/1000 - Train Loss: 0.1400 - Val Loss: 0.0998 (Best Model Saved)
# Epoch 287/1000 - Train Loss: 0.1559 - Val Loss: 0.0991 (Best Model Saved)
# Epoch 288/1000 - Train Loss: 0.1221 - Val Loss: 0.0986 (Best Model Saved)
# Epoch 289/1000 - Train Loss: 0.1261 - Val Loss: 0.0982 (Best Model Saved)
# Epoch 290/1000 - Train Loss: 0.1320 - Val Loss: 0.0980 (Best Model Saved)
# Epoch 291/1000 - Train Loss: 0.1518 - Val Loss: 0.0976 (Best Model Saved)
# Epoch 292/1000 - Train Loss: 0.1372 - Val Loss: 0.0975 (Best Model Saved)
# Epoch 293/1000 - Train Loss: 0.1349 - Val Loss: 0.0979
# Epoch 294/1000 - Train Loss: 0.1942 - Val Loss: 0.0978
# Epoch 295/1000 - Train Loss: 0.1264 - Val Loss: 0.0972 (Best Model Saved)
# Epoch 296/1000 - Train Loss: 0.1305 - Val Loss: 0.0956 (Best Model Saved)
# Epoch 297/1000 - Train Loss: 0.1754 - Val Loss: 0.0950 (Best Model Saved)
# Epoch 298/1000 - Train Loss: 0.1439 - Val Loss: 0.0953
# Epoch 299/1000 - Train Loss: 0.1369 - Val Loss: 0.0958
# Epoch 300/1000 - Train Loss: 0.1162 - Val Loss: 0.0953
# Epoch 301/1000 - Train Loss: 0.1451 - Val Loss: 0.0943 (Best Model Saved)
# Epoch 302/1000 - Train Loss: 0.1281 - Val Loss: 0.0937 (Best Model Saved)
# Epoch 303/1000 - Train Loss: 0.1068 - Val Loss: 0.0930 (Best Model Saved)
# Epoch 304/1000 - Train Loss: 0.1388 - Val Loss: 0.0919 (Best Model Saved)
# Epoch 305/1000 - Train Loss: 0.1641 - Val Loss: 0.0913 (Best Model Saved)
# Epoch 306/1000 - Train Loss: 0.1193 - Val Loss: 0.0917
# Epoch 307/1000 - Train Loss: 0.1175 - Val Loss: 0.0913 (Best Model Saved)
# Epoch 308/1000 - Train Loss: 0.1139 - Val Loss: 0.0904 (Best Model Saved)
# Epoch 309/1000 - Train Loss: 0.1161 - Val Loss: 0.0898 (Best Model Saved)
# Epoch 310/1000 - Train Loss: 0.1224 - Val Loss: 0.0892 (Best Model Saved)
# Epoch 311/1000 - Train Loss: 0.1460 - Val Loss: 0.0888 (Best Model Saved)
# Epoch 312/1000 - Train Loss: 0.1373 - Val Loss: 0.0889
# Epoch 313/1000 - Train Loss: 0.1388 - Val Loss: 0.0895
# Epoch 314/1000 - Train Loss: 0.0994 - Val Loss: 0.0896
# Epoch 315/1000 - Train Loss: 0.1035 - Val Loss: 0.0887 (Best Model Saved)
# Epoch 316/1000 - Train Loss: 0.0978 - Val Loss: 0.0883 (Best Model Saved)
# Epoch 317/1000 - Train Loss: 0.1528 - Val Loss: 0.0878 (Best Model Saved)
# Epoch 318/1000 - Train Loss: 0.1077 - Val Loss: 0.0888
# Epoch 319/1000 - Train Loss: 0.1345 - Val Loss: 0.0890
# Epoch 320/1000 - Train Loss: 0.1230 - Val Loss: 0.0867 (Best Model Saved)
# Epoch 321/1000 - Train Loss: 0.1200 - Val Loss: 0.0845 (Best Model Saved)
# Epoch 322/1000 - Train Loss: 0.1189 - Val Loss: 0.0837 (Best Model Saved)
# Epoch 323/1000 - Train Loss: 0.0945 - Val Loss: 0.0831 (Best Model Saved)
# Epoch 324/1000 - Train Loss: 0.1297 - Val Loss: 0.0832
# Epoch 325/1000 - Train Loss: 0.1290 - Val Loss: 0.0829 (Best Model Saved)
# Epoch 326/1000 - Train Loss: 0.1259 - Val Loss: 0.0822 (Best Model Saved)
# Epoch 327/1000 - Train Loss: 0.1270 - Val Loss: 0.0812 (Best Model Saved)
# Epoch 328/1000 - Train Loss: 0.1426 - Val Loss: 0.0809 (Best Model Saved)
# Epoch 329/1000 - Train Loss: 0.1073 - Val Loss: 0.0812
# Epoch 330/1000 - Train Loss: 0.1080 - Val Loss: 0.0809 (Best Model Saved)
# Epoch 331/1000 - Train Loss: 0.1169 - Val Loss: 0.0808 (Best Model Saved)
# Epoch 332/1000 - Train Loss: 0.0943 - Val Loss: 0.0811
# Epoch 333/1000 - Train Loss: 0.1060 - Val Loss: 0.0811
# Epoch 334/1000 - Train Loss: 0.1242 - Val Loss: 0.0805 (Best Model Saved)
# Epoch 335/1000 - Train Loss: 0.1195 - Val Loss: 0.0803 (Best Model Saved)
# Epoch 336/1000 - Train Loss: 0.1281 - Val Loss: 0.0801 (Best Model Saved)
# Epoch 337/1000 - Train Loss: 0.1059 - Val Loss: 0.0800 (Best Model Saved)
# Epoch 338/1000 - Train Loss: 0.1086 - Val Loss: 0.0802
# Epoch 339/1000 - Train Loss: 0.1209 - Val Loss: 0.0804
# Epoch 340/1000 - Train Loss: 0.0982 - Val Loss: 0.0805
# Epoch 341/1000 - Train Loss: 0.0874 - Val Loss: 0.0804
# Epoch 342/1000 - Train Loss: 0.1409 - Val Loss: 0.0801
# Epoch 343/1000 - Train Loss: 0.1143 - Val Loss: 0.0800 (Best Model Saved)
# Epoch 344/1000 - Train Loss: 0.0877 - Val Loss: 0.0793 (Best Model Saved)
# Epoch 345/1000 - Train Loss: 0.1012 - Val Loss: 0.0787 (Best Model Saved)
# Epoch 346/1000 - Train Loss: 0.1355 - Val Loss: 0.0785 (Best Model Saved)
# Epoch 347/1000 - Train Loss: 0.0945 - Val Loss: 0.0789
# Epoch 348/1000 - Train Loss: 0.1079 - Val Loss: 0.0795
# Epoch 349/1000 - Train Loss: 0.1374 - Val Loss: 0.0801
# Epoch 350/1000 - Train Loss: 0.0889 - Val Loss: 0.0801
# Epoch 351/1000 - Train Loss: 0.1187 - Val Loss: 0.0785
# Epoch 352/1000 - Train Loss: 0.1053 - Val Loss: 0.0783 (Best Model Saved)
# Epoch 353/1000 - Train Loss: 0.1188 - Val Loss: 0.0780 (Best Model Saved)
# Epoch 354/1000 - Train Loss: 0.1389 - Val Loss: 0.0807
# Epoch 355/1000 - Train Loss: 0.1405 - Val Loss: 0.0815
# Epoch 356/1000 - Train Loss: 0.1320 - Val Loss: 0.0795
# Epoch 357/1000 - Train Loss: 0.0917 - Val Loss: 0.0787
# Epoch 358/1000 - Train Loss: 0.1114 - Val Loss: 0.0782
# Epoch 359/1000 - Train Loss: 0.0890 - Val Loss: 0.0789
# Epoch 360/1000 - Train Loss: 0.1249 - Val Loss: 0.0805
# Epoch 361/1000 - Train Loss: 0.0908 - Val Loss: 0.0788
# Epoch 362/1000 - Train Loss: 0.1265 - Val Loss: 0.0771 (Best Model Saved)
# Epoch 363/1000 - Train Loss: 0.1105 - Val Loss: 0.0771 (Best Model Saved)
# Epoch 364/1000 - Train Loss: 0.1065 - Val Loss: 0.0780
# Epoch 365/1000 - Train Loss: 0.1101 - Val Loss: 0.0792
# Epoch 366/1000 - Train Loss: 0.0816 - Val Loss: 0.0779
# Epoch 367/1000 - Train Loss: 0.1111 - Val Loss: 0.0762 (Best Model Saved)
# Epoch 368/1000 - Train Loss: 0.0899 - Val Loss: 0.0756 (Best Model Saved)
# Epoch 369/1000 - Train Loss: 0.1015 - Val Loss: 0.0756 (Best Model Saved)
# Epoch 370/1000 - Train Loss: 0.1016 - Val Loss: 0.0773
# Epoch 371/1000 - Train Loss: 0.0923 - Val Loss: 0.0794
# Epoch 372/1000 - Train Loss: 0.0994 - Val Loss: 0.0767
# Epoch 373/1000 - Train Loss: 0.0809 - Val Loss: 0.0753 (Best Model Saved)
# Epoch 374/1000 - Train Loss: 0.1023 - Val Loss: 0.0751 (Best Model Saved)
# Epoch 375/1000 - Train Loss: 0.0944 - Val Loss: 0.0754
# Epoch 376/1000 - Train Loss: 0.0798 - Val Loss: 0.0771
# Epoch 377/1000 - Train Loss: 0.0880 - Val Loss: 0.0761
# Epoch 378/1000 - Train Loss: 0.0843 - Val Loss: 0.0735 (Best Model Saved)
# Epoch 379/1000 - Train Loss: 0.0999 - Val Loss: 0.0732 (Best Model Saved)
# Epoch 380/1000 - Train Loss: 0.1050 - Val Loss: 0.0753
# Epoch 381/1000 - Train Loss: 0.0924 - Val Loss: 0.0822
# Epoch 382/1000 - Train Loss: 0.1000 - Val Loss: 0.0785
# Epoch 383/1000 - Train Loss: 0.0938 - Val Loss: 0.0725 (Best Model Saved)
# Epoch 384/1000 - Train Loss: 0.1180 - Val Loss: 0.0728
# Epoch 385/1000 - Train Loss: 0.0890 - Val Loss: 0.0780
# Epoch 386/1000 - Train Loss: 0.1061 - Val Loss: 0.0775
# Epoch 387/1000 - Train Loss: 0.0799 - Val Loss: 0.0732
# Epoch 388/1000 - Train Loss: 0.1025 - Val Loss: 0.0726
# Epoch 389/1000 - Train Loss: 0.0818 - Val Loss: 0.0739
# Epoch 390/1000 - Train Loss: 0.0893 - Val Loss: 0.0762
# Epoch 391/1000 - Train Loss: 0.0815 - Val Loss: 0.0728
# Epoch 392/1000 - Train Loss: 0.0928 - Val Loss: 0.0702 (Best Model Saved)
# Epoch 393/1000 - Train Loss: 0.0824 - Val Loss: 0.0704
# Epoch 394/1000 - Train Loss: 0.0721 - Val Loss: 0.0724
# Epoch 395/1000 - Train Loss: 0.0885 - Val Loss: 0.0713
# Epoch 396/1000 - Train Loss: 0.0950 - Val Loss: 0.0699 (Best Model Saved)
# Epoch 397/1000 - Train Loss: 0.1009 - Val Loss: 0.0703
# Epoch 398/1000 - Train Loss: 0.0817 - Val Loss: 0.0712
# Epoch 399/1000 - Train Loss: 0.0731 - Val Loss: 0.0699
# Epoch 400/1000 - Train Loss: 0.1033 - Val Loss: 0.0693 (Best Model Saved)
# Epoch 401/1000 - Train Loss: 0.0772 - Val Loss: 0.0689 (Best Model Saved)
# Epoch 402/1000 - Train Loss: 0.0929 - Val Loss: 0.0690
# Epoch 403/1000 - Train Loss: 0.0745 - Val Loss: 0.0708
# Epoch 404/1000 - Train Loss: 0.0821 - Val Loss: 0.0702
# Epoch 405/1000 - Train Loss: 0.1083 - Val Loss: 0.0692
# Epoch 406/1000 - Train Loss: 0.0645 - Val Loss: 0.0709
# Epoch 407/1000 - Train Loss: 0.0744 - Val Loss: 0.0709
# Epoch 408/1000 - Train Loss: 0.0824 - Val Loss: 0.0680 (Best Model Saved)
# Epoch 409/1000 - Train Loss: 0.0973 - Val Loss: 0.0685
# Epoch 410/1000 - Train Loss: 0.0920 - Val Loss: 0.0758
# Epoch 411/1000 - Train Loss: 0.0763 - Val Loss: 0.0759
# Epoch 412/1000 - Train Loss: 0.0795 - Val Loss: 0.0689
# Epoch 413/1000 - Train Loss: 0.0757 - Val Loss: 0.0681
# Epoch 414/1000 - Train Loss: 0.0843 - Val Loss: 0.0724
# Epoch 415/1000 - Train Loss: 0.0721 - Val Loss: 0.0780
# Epoch 416/1000 - Train Loss: 0.0623 - Val Loss: 0.0728
# Epoch 417/1000 - Train Loss: 0.0807 - Val Loss: 0.0689
# Epoch 418/1000 - Train Loss: 0.1065 - Val Loss: 0.0709
# Epoch 419/1000 - Train Loss: 0.0813 - Val Loss: 0.0769
# Epoch 420/1000 - Train Loss: 0.0833 - Val Loss: 0.0788
# Epoch 421/1000 - Train Loss: 0.1007 - Val Loss: 0.0731
# Epoch 422/1000 - Train Loss: 0.0745 - Val Loss: 0.0706
# Epoch 423/1000 - Train Loss: 0.0917 - Val Loss: 0.0716
# Epoch 424/1000 - Train Loss: 0.0715 - Val Loss: 0.0754
# Epoch 425/1000 - Train Loss: 0.0624 - Val Loss: 0.0751
# Epoch 426/1000 - Train Loss: 0.0699 - Val Loss: 0.0708
# Epoch 427/1000 - Train Loss: 0.0792 - Val Loss: 0.0696
# Epoch 428/1000 - Train Loss: 0.0858 - Val Loss: 0.0756
# Early stopping triggered after 428 epochs
# Best validation loss: 0.0680 for epoch 407
# Test MAE: 32.5235
# Test MSE: 2821.4805
