# %% [markdown]
# # 1 Dataset and Task
#  (a) Select your choice of neural networks model that is suitable for this task and motivate it. Train your model
#  to predict one step ahead data point, during training (see following Figure). Scale your data before training
#  and scale them back to be able to compare your predictions with real measurements.
#
#  (b) How many past time steps should you input into your network to achieve the best possible performance?
#  (Hint: This is a tunable parameter and needs to be tuned).
#
#  (c) Once your model is trained, use it to predict the next 200 data points recursively. This means feeding each
#  prediction back into the model to generate the subsequent predictions.)
#
#  (d) On May 9th, download the real test dataset and evaluate your model by reporting both the Mean Absolute
#  Error (MAE) and Mean Squared Error (MSE) between its predictions and the actual test values. Additionally,
#  create a plot comparing the predicted and real values to visually assess your models performance.

# %% [markdown]
# First, we load the data and take a look at it. We also install torch:

# %%
file = 'Xtrain.mat'
# load training data
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn

# Load the training data
data = scipy.io.loadmat(file)
X_train = data['Xtrain']

# Display basic information about the data
print(f"Data shape: {X_train.shape}")
print(f"Data type: {X_train.dtype}")
print(f"Min value: {np.min(X_train)}")
print(f"Max value: {np.max(X_train)}")

# plot the data
plt.plot(X_train)
plt.show()
# Out:
# Data shape: (1000, 1)
# Data type: uint8
# Min value: 2
# Max value: 255

# %% [markdown]
# Now, we scale the data, because then the network works better and faster.
# I also want to scale it back, so that it can get the right outputs.

# %%
import sklearn
from sklearn.preprocessing import StandardScaler

#let's scale the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(X_train.reshape(-1, 1))

#We also want the scaled back data ready:
restored_data = scaler.inverse_transform(scaled_data)

# Printing the first few values of the scaled and restored data to check
print(f"First few scaled values:\n{scaled_data[:5]}")
print(f"First few restored values:\n{restored_data[:5]}")

#Display basic information about the data
print(f"Data shape: {scaled_data.shape}")
print(f"Data type: {scaled_data.dtype}")
print(f"Min value: {np.min(scaled_data)}")
print(f"Max value: {np.max(scaled_data)}")
# Out:
# First few scaled values:
# [[ 0.55720154]
#  [ 1.73111118]
#  [ 0.74929585]
#  [-0.40326998]
#  [-0.8088024 ]]
# First few restored values:
# [[ 86.]
#  [141.]
#  [ 95.]
#  [ 41.]
#  [ 22.]]
# Data shape: (1000, 1)
# Data type: float64
# Min value: -1.2356786270219065
# Max value: 4.16430570013708

# %%
#making the LSTM
class LSTMModel(nn.Module):
    def __init__(self, input_size=1, hidden_size=64, num_layers=1, dropout=0.2):
        super().__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, 1)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, x):
        out, _ = self.lstm(x)
        out = out[:, -1, :]  # use output from last time step
        out = self.dropout(out)
        out = self.fc(out)
        return out

# %%
from torch.utils.data import TensorDataset, DataLoader
#Now we want to create sequences from our data, then split into training and validation sets
seq_len = 30

#Define the function that retrieves the sequences:
def create_sequences(data, seq_len):
    sequences = []
    labels = []
    for i in range(len(data) - seq_len):
        seq = data[i:i+seq_len]
        label = data[i+seq_len]
        sequences.append(seq)
        labels.append(label)
    return np.array(sequences), np.array(labels)

# Define the split ratio for validation data
train_ratio = 0.9
val_ratio = 0.1

# Create sequences from scaled data
X_sequences, y_labels = create_sequences(scaled_data, seq_len)

# Convert to PyTorch tensors
X_sequences = torch.tensor(X_sequences, dtype=torch.float32)
y_labels = torch.tensor(y_labels, dtype=torch.float32)

# Create a TensorDataset
dataset = TensorDataset(X_sequences, y_labels)

# Calculate sizes for train and validation
dataset_size = len(dataset)
train_size = int(train_ratio * dataset_size)
val_size = dataset_size - train_size

# Split the dataset for train and validation
train_dataset, val_dataset = torch.utils.data.random_split(
    dataset, [train_size, val_size],
    generator=torch.Generator().manual_seed(42)
)

# Create DataLoaders for training and validation
batch_size = 512
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# Print information about the splits
print(f"Total sequences: {dataset_size}")
print(f"Training sequences: {train_size}")
print(f"Validation sequences: {val_size}")
# Out:
# Total sequences: 970
# Training sequences: 873
# Validation sequences: 97

# %%
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader, Subset
from sklearn.model_selection import KFold

# hyperparameter tuning for seq_len
seq_len_options = [20,22,25,27,30,32,35,37,40,42,45,47,50]
k_folds = 5
hyperparameter_tuning_results = {}

device = torch.device('cuda' if torch.cuda.is_available() else 'mps')
print(f"Device for tuning: {device}")

# training parameters
num_epochs_tuning = 5000
patience_tuning = 20
batch_size_tuning = 512
lr_tuning = 0.0001
kfold_random_state = 42

for current_seq_len in seq_len_options:
    print(f"\n--- Evaluating seq_len: {current_seq_len} ---")

    # create sequences for current seq_len
    X_sequences_tune, y_labels_tune = create_sequences(scaled_data, current_seq_len)

    # convert to tensors and create dataset
    X_sequences_tune_tensor = torch.tensor(X_sequences_tune, dtype=torch.float32)
    y_labels_tune_tensor = torch.tensor(y_labels_tune, dtype=torch.float32)
    dataset_tune = TensorDataset(X_sequences_tune_tensor, y_labels_tune_tensor)
    
    dataset_size_tune = len(dataset_tune)
    print(f"  Total sequences for seq_len {current_seq_len}: {dataset_size_tune}")

    all_fold_best_val_losses = []
    
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=kfold_random_state)

    for fold_num, (train_idx, val_idx) in enumerate(kf.split(dataset_tune)):
        print(f"  --- Fold {fold_num + 1}/{k_folds} for seq_len: {current_seq_len} ---")
        
        train_dataset_tune = Subset(dataset_tune, train_idx)
        val_dataset_tune = Subset(dataset_tune, val_idx)

        train_loader_tune = DataLoader(train_dataset_tune, batch_size=batch_size_tuning, shuffle=True)
        val_loader_tune = DataLoader(val_dataset_tune, batch_size=batch_size_tuning, shuffle=False)

        print(f"  Training sequences: {len(train_dataset_tune)}, Validation sequences: {len(val_dataset_tune)}")

        # initialize model for this fold
        model_tune = LSTMModel(hidden_size=64, num_layers=1, dropout=0.1).to(device) 
        criterion_tune = nn.MSELoss()
        optimizer_tune = torch.optim.Adam(model_tune.parameters(), lr=lr_tuning)

        current_best_val_loss_for_this_fold = float('inf')
        epochs_no_improve_tune = 0
        
        for epoch in range(num_epochs_tuning):
            model_tune.train()
            epoch_train_loss = 0
            for X_batch, y_batch in train_loader_tune:
                X_batch, y_batch = X_batch.to(device), y_batch.to(device)
                optimizer_tune.zero_grad()
                output = model_tune(X_batch)
                loss = criterion_tune(output.squeeze(), y_batch.squeeze())
                loss.backward()
                optimizer_tune.step()
                epoch_train_loss += loss.item()
            epoch_train_loss /= len(train_loader_tune)

            model_tune.eval()
            epoch_val_loss = 0
            with torch.no_grad():
                for X_batch, y_batch in val_loader_tune:
                    X_batch, y_batch = X_batch.to(device), y_batch.to(device)
                    output = model_tune(X_batch)
                    loss = criterion_tune(output.squeeze(), y_batch.squeeze())
                    epoch_val_loss += loss.item()
            epoch_val_loss /= len(val_loader_tune)
            
            if epoch_val_loss < current_best_val_loss_for_this_fold:
                current_best_val_loss_for_this_fold = epoch_val_loss
                epochs_no_improve_tune = 0
            else:
                epochs_no_improve_tune += 1
            
            if (epoch + 1) % 200 == 0 or epoch == num_epochs_tuning - 1 or epochs_no_improve_tune >= patience_tuning:
                 print(f"    Epoch {epoch+1}/{num_epochs_tuning} - Train: {epoch_train_loss:.5f} - Val: {epoch_val_loss:.5f} (Best Fold: {current_best_val_loss_for_this_fold:.5f})")

            if epochs_no_improve_tune >= patience_tuning:
                print(f"    Early stopping at epoch {epoch+1}. Best Val Loss for Fold: {current_best_val_loss_for_this_fold:.5f}")
                break
        
        all_fold_best_val_losses.append(current_best_val_loss_for_this_fold)
        print(f"  --- Fold {fold_num + 1} finished. Best Val Loss: {current_best_val_loss_for_this_fold:.5f} ---")

    mean_best_val_loss = float('inf')
    std_best_val_loss = float('nan')
    if all_fold_best_val_losses: 
        valid_losses = [loss for loss in all_fold_best_val_losses if loss != float('inf')]
        if valid_losses:
            mean_best_val_loss = np.mean(valid_losses)
            std_best_val_loss = np.std(valid_losses)
        
    hyperparameter_tuning_results[current_seq_len] = {
        'mean_best_val_loss': mean_best_val_loss,
        'std_best_val_loss': std_best_val_loss,
        'individual_trial_losses': all_fold_best_val_losses
    }
    print(f"--- Finished seq_len: {current_seq_len}. Mean Val Loss: {mean_best_val_loss:.5f} (Std: {std_best_val_loss:.5f}) ---")

best_seq_len_final = None
lowest_overall_mean_val_loss = float('inf')

if hyperparameter_tuning_results:
    for sl, results_dict in hyperparameter_tuning_results.items():
        current_mean_loss = results_dict.get('mean_best_val_loss', float('inf'))
        if current_mean_loss < lowest_overall_mean_val_loss:
            lowest_overall_mean_val_loss = current_mean_loss
            best_seq_len_final = sl

print(f"\n--- Hyperparameter Tuning Complete (K-Fold CV) ---")
print(f"All results:")
for sl, res_dict in sorted(hyperparameter_tuning_results.items()): 
    mean_loss = res_dict.get('mean_best_val_loss', float('inf'))
    std_loss = res_dict.get('std_best_val_loss', float('nan'))
    fold_losses = res_dict.get('individual_trial_losses', [])
    formatted_fold_losses = [f"{loss:.5f}" if loss != float('inf') else "inf" for loss in fold_losses]
    print(f"  Seq_len: {sl:3d} -> Mean: {mean_loss:.5f}, Std: {std_loss:.5f}, Fold Losses: {formatted_fold_losses}")

if best_seq_len_final is not None:
    print(f"\nBest sequence length: {best_seq_len_final}")
    print(f"Lowest mean validation loss: {lowest_overall_mean_val_loss:.5f}")
else:
    print("\nNo best sequence length found. All runs might have failed or been skipped.")
# Out:
# Device for tuning: mps
# Starting hyperparameter tuning for seq_len with 5-fold cross-validation...
#
# --- Evaluating seq_len: 20 ---
#   Total sequences for seq_len 20: 980
#   --- Fold 1/5 for seq_len: 20 ---
#   Training sequences: 784, Validation sequences: 196
#     Epoch 200/5000 - Train: 0.24120 - Val: 0.27226 (Best Fold: 0.27226)
#     Epoch 400/5000 - Train: 0.07528 - Val: 0.15309 (Best Fold: 0.15243)
#     Epoch 433/5000 - Train: 0.06415 - Val: 0.14987 (Best Fold: 0.14985)
#     Early stopping at epoch 433. Best Val Loss for Fold: 0.14985
#   --- Fold 1 finished. Best Val Loss: 0.14985 ---
#   --- Fold 2/5 for seq_len: 20 ---
#   Training sequences: 784, Validation sequences: 196
#     Epoch 200/5000 - Train: 0.24340 - Val: 0.26752 (Best Fold: 0.26752)
#     Epoch 400/5000 - Train: 0.13332 - Val: 0.11566 (Best Fold: 0.11566)
#     Epoch 498/5000 - Train: 0.07355 - Val: 0.08357 (Best Fold: 0.08152)
#     Early stopping at epoch 498. Best Val Loss for Fold: 0.08152
#   --- Fold 2 finished. Best Val Loss: 0.08152 ---
#   --- Fold 3/5 for seq_len: 20 ---
#   Training sequences: 784, Validation sequences: 196
#     Epoch 200/5000 - Train: 0.22731 - Val: 0.21305 (Best Fold: 0.21305)
#     Epoch 400/5000 - Train: 0.08932 - Val: 0.07199 (Best Fold: 0.07192)
#     Epoch 567/5000 - Train: 0.06026 - Val: 0.04911 (Best Fold: 0.04503)
#     Early stopping at epoch 567. Best Val Loss for Fold: 0.04503
#   --- Fold 3 finished. Best Val Loss: 0.04503 ---
#   --- Fold 4/5 for seq_len: 20 ---
#   Training sequences: 784, Validation sequences: 196
#     Epoch 200/5000 - Train: 0.24159 - Val: 0.23563 (Best Fold: 0.23563)
#     Epoch 400/5000 - Train: 0.09457 - Val: 0.07292 (Best Fold: 0.07292)
#     Epoch 548/5000 - Train: 0.05485 - Val: 0.05578 (Best Fold: 0.05501)
#     Early stopping at epoch 548. Best Val Loss for Fold: 0.05501
#   --- Fold 4 finished. Best Val Loss: 0.05501 ---
#   --- Fold 5/5 for seq_len: 20 ---
#   Training sequences: 784, Validation sequences: 196
#     Epoch 200/5000 - Train: 0.25380 - Val: 0.20703 (Best Fold: 0.20703)
#     Epoch 400/5000 - Train: 0.09757 - Val: 0.06704 (Best Fold: 0.06704)
#     Epoch 480/5000 - Train: 0.06975 - Val: 0.06561 (Best Fold: 0.05643)
#     Early stopping at epoch 480. Best Val Loss for Fold: 0.05643
#   --- Fold 5 finished. Best Val Loss: 0.05643 ---
# --- Finished seq_len: 20. Mean Val Loss: 0.07757 (Std: 0.03809) ---
#
# --- Evaluating seq_len: 22 ---
#   Total sequences for seq_len 22: 978
#   --- Fold 1/5 for seq_len: 22 ---
#   Training sequences: 782, Validation sequences: 196
#     Epoch 200/5000 - Train: 0.23363 - Val: 0.24497 (Best Fold: 0.24497)
#     Epoch 400/5000 - Train: 0.07011 - Val: 0.13693 (Best Fold: 0.13693)
#     Epoch 600/5000 - Train: 0.04234 - Val: 0.10157 (Best Fold: 0.09980)
#     Epoch 728/5000 - Train: 0.03345 - Val: 0.09700 (Best Fold: 0.09326)
#     Early stopping at epoch 728. Best Val Loss for Fold: 0.09326
#   --- Fold 1 finished. Best Val Loss: 0.09326 ---
#   --- Fold 2/5 for seq_len: 22 ---
#   Training sequences: 782, Validation sequences: 196
#     Epoch 200/5000 - Train: 0.22964 - Val: 0.25797 (Best Fold: 0.25797)
#     Epoch 400/5000 - Train: 0.09885 - Val: 0.07395 (Best Fold: 0.07395)
#     Epoch 538/5000 - Train: 0.06872 - Val: 0.06485 (Best Fold: 0.06006)
#     Early stopping at epoch 538. Best Val Loss for Fold: 0.06006
#   --- Fold 2 finished. Best Val Loss: 0.06006 ---
#   --- Fold 3/5 for seq_len: 22 ---
#   Training sequences: 782, Validation sequences: 196
#     Epoch 200/5000 - Train: 0.26321 - Val: 0.19955 (Best Fold: 0.19955)
#     Epoch 400/5000 - Train: 0.08730 - Val: 0.05906 (Best Fold: 0.05631)
#     Epoch 600/5000 - Train: 0.05364 - Val: 0.03520 (Best Fold: 0.03470)
#     Early stopping at epoch 600. Best Val Loss for Fold: 0.03470
#   --- Fold 3 finished. Best Val Loss: 0.03470 ---
#   --- Fold 4/5 for seq_len: 22 ---
#   Training sequences: 783, Validation sequences: 195
#     Epoch 200/5000 - Train: 0.28538 - Val: 0.16170 (Best Fold: 0.16170)
#     Epoch 400/5000 - Train: 0.09351 - Val: 0.03912 (Best Fold: 0.03767)
#     Epoch 421/5000 - Train: 0.07931 - Val: 0.04064 (Best Fold: 0.03661)
#     Early stopping at epoch 421. Best Val Loss for Fold: 0.03661
#   --- Fold 4 finished. Best Val Loss: 0.03661 ---
#   --- Fold 5/5 for seq_len: 22 ---
#   Training sequences: 783, Validation sequences: 195
#     Epoch 200/5000 - Train: 0.21207 - Val: 0.33394 (Best Fold: 0.33394)
#     Epoch 400/5000 - Train: 0.09725 - Val: 0.13669 (Best Fold: 0.13669)
#     Epoch 600/5000 - Train: 0.05617 - Val: 0.06240 (Best Fold: 0.05519)
#     Epoch 800/5000 - Train: 0.03618 - Val: 0.03333 (Best Fold: 0.02915)
#     Epoch 843/5000 - Train: 0.03885 - Val: 0.03616 (Best Fold: 0.02642)
#     Early stopping at epoch 843. Best Val Loss for Fold: 0.02642
#   --- Fold 5 finished. Best Val Loss: 0.02642 ---
# --- Finished seq_len: 22. Mean Val Loss: 0.05021 (Std: 0.02426) ---
#
# --- Evaluating seq_len: 25 ---
#   Total sequences for seq_len 25: 975
#   --- Fold 1/5 for seq_len: 25 ---
#   Training sequences: 780, Validation sequences: 195
#     Epoch 200/5000 - Train: 0.21865 - Val: 0.32991 (Best Fold: 0.32991)
#     Epoch 400/5000 - Train: 0.07625 - Val: 0.14505 (Best Fold: 0.14505)
#     Epoch 600/5000 - Train: 0.04164 - Val: 0.08724 (Best Fold: 0.08724)
#     Epoch 698/5000 - Train: 0.03940 - Val: 0.09785 (Best Fold: 0.08497)
#     Early stopping at epoch 698. Best Val Loss for Fold: 0.08497
#   --- Fold 1 finished. Best Val Loss: 0.08497 ---
#   --- Fold 2/5 for seq_len: 25 ---
#   Training sequences: 780, Validation sequences: 195
#     Epoch 200/5000 - Train: 0.24714 - Val: 0.26855 (Best Fold: 0.26855)
#     Epoch 400/5000 - Train: 0.07665 - Val: 0.06023 (Best Fold: 0.06023)
#     Epoch 579/5000 - Train: 0.06055 - Val: 0.04244 (Best Fold: 0.04027)
#     Early stopping at epoch 579. Best Val Loss for Fold: 0.04027
#   --- Fold 2 finished. Best Val Loss: 0.04027 ---
#   --- Fold 3/5 for seq_len: 25 ---
#   Training sequences: 780, Validation sequences: 195
#     Epoch 200/5000 - Train: 0.24488 - Val: 0.19136 (Best Fold: 0.19136)
#     Epoch 400/5000 - Train: 0.09778 - Val: 0.07212 (Best Fold: 0.06202)
#     Epoch 429/5000 - Train: 0.08630 - Val: 0.06850 (Best Fold: 0.06072)
#     Early stopping at epoch 429. Best Val Loss for Fold: 0.06072
#   --- Fold 3 finished. Best Val Loss: 0.06072 ---
#   --- Fold 4/5 for seq_len: 25 ---
#   Training sequences: 780, Validation sequences: 195
#     Epoch 200/5000 - Train: 0.25016 - Val: 0.21421 (Best Fold: 0.21421)
#     Epoch 400/5000 - Train: 0.09737 - Val: 0.10911 (Best Fold: 0.10911)
#     Epoch 522/5000 - Train: 0.06822 - Val: 0.08085 (Best Fold: 0.07748)
#     Early stopping at epoch 522. Best Val Loss for Fold: 0.07748
#   --- Fold 4 finished. Best Val Loss: 0.07748 ---
#   --- Fold 5/5 for seq_len: 25 ---
#   Training sequences: 780, Validation sequences: 195
#     Epoch 200/5000 - Train: 0.27312 - Val: 0.20012 (Best Fold: 0.20012)
#     Epoch 400/5000 - Train: 0.08779 - Val: 0.06165 (Best Fold: 0.05737)
#     Epoch 461/5000 - Train: 0.07972 - Val: 0.05622 (Best Fold: 0.05445)
#     Early stopping at epoch 461. Best Val Loss for Fold: 0.05445
#   --- Fold 5 finished. Best Val Loss: 0.05445 ---
# --- Finished seq_len: 25. Mean Val Loss: 0.06358 (Std: 0.01604) ---
#
# --- Evaluating seq_len: 27 ---
#   Total sequences for seq_len 27: 973
#   --- Fold 1/5 for seq_len: 27 ---
#   Training sequences: 778, Validation sequences: 195
#     Epoch 200/5000 - Train: 0.22052 - Val: 0.27539 (Best Fold: 0.27539)
#     Epoch 400/5000 - Train: 0.06307 - Val: 0.14369 (Best Fold: 0.14103)
#     Epoch 584/5000 - Train: 0.04340 - Val: 0.11784 (Best Fold: 0.11660)
#     Early stopping at epoch 584. Best Val Loss for Fold: 0.11660
#   --- Fold 1 finished. Best Val Loss: 0.11660 ---
#   --- Fold 2/5 for seq_len: 27 ---
#   Training sequences: 778, Validation sequences: 195
#     Epoch 200/5000 - Train: 0.21092 - Val: 0.26979 (Best Fold: 0.26979)
#     Epoch 400/5000 - Train: 0.07153 - Val: 0.09231 (Best Fold: 0.08723)
#     Epoch 600/5000 - Train: 0.05387 - Val: 0.05297 (Best Fold: 0.04535)
#     Epoch 777/5000 - Train: 0.05513 - Val: 0.03449 (Best Fold: 0.03403)
#     Early stopping at epoch 777. Best Val Loss for Fold: 0.03403
#   --- Fold 2 finished. Best Val Loss: 0.03403 ---
#   --- Fold 3/5 for seq_len: 27 ---
#   Training sequences: 778, Validation sequences: 195
#     Epoch 200/5000 - Train: 0.22682 - Val: 0.22306 (Best Fold: 0.22306)
#     Epoch 400/5000 - Train: 0.08373 - Val: 0.03505 (Best Fold: 0.03493)
#     Epoch 503/5000 - Train: 0.05883 - Val: 0.02832 (Best Fold: 0.02772)
#     Early stopping at epoch 503. Best Val Loss for Fold: 0.02772
#   --- Fold 3 finished. Best Val Loss: 0.02772 ---
#   --- Fold 4/5 for seq_len: 27 ---
#   Training sequences: 779, Validation sequences: 194
#     Epoch 200/5000 - Train: 0.24600 - Val: 0.16015 (Best Fold: 0.16015)
#     Epoch 400/5000 - Train: 0.07676 - Val: 0.04466 (Best Fold: 0.04348)
#     Epoch 439/5000 - Train: 0.06196 - Val: 0.06230 (Best Fold: 0.03856)
#     Early stopping at epoch 439. Best Val Loss for Fold: 0.03856
#   --- Fold 4 finished. Best Val Loss: 0.03856 ---
#   --- Fold 5/5 for seq_len: 27 ---
#   Training sequences: 779, Validation sequences: 194
#     Epoch 200/5000 - Train: 0.24904 - Val: 0.20888 (Best Fold: 0.20888)
#     Epoch 400/5000 - Train: 0.08204 - Val: 0.07479 (Best Fold: 0.07479)
#     Epoch 458/5000 - Train: 0.07724 - Val: 0.06723 (Best Fold: 0.06338)
#     Early stopping at epoch 458. Best Val Loss for Fold: 0.06338
#   --- Fold 5 finished. Best Val Loss: 0.06338 ---
# --- Finished seq_len: 27. Mean Val Loss: 0.05606 (Std: 0.03260) ---
#
# --- Evaluating seq_len: 30 ---
#   Total sequences for seq_len 30: 970
#   --- Fold 1/5 for seq_len: 30 ---
#   Training sequences: 776, Validation sequences: 194
#     Epoch 200/5000 - Train: 0.22220 - Val: 0.23871 (Best Fold: 0.23871)
#     Epoch 400/5000 - Train: 0.06914 - Val: 0.13484 (Best Fold: 0.13360)
#     Epoch 600/5000 - Train: 0.04508 - Val: 0.10637 (Best Fold: 0.10595)
#     Epoch 640/5000 - Train: 0.04553 - Val: 0.10332 (Best Fold: 0.10085)
#     Early stopping at epoch 640. Best Val Loss for Fold: 0.10085
#   --- Fold 1 finished. Best Val Loss: 0.10085 ---
#   --- Fold 2/5 for seq_len: 30 ---
#   Training sequences: 776, Validation sequences: 194
#     Epoch 200/5000 - Train: 0.23178 - Val: 0.27422 (Best Fold: 0.27422)
#     Epoch 400/5000 - Train: 0.08274 - Val: 0.13654 (Best Fold: 0.13654)
#     Epoch 516/5000 - Train: 0.05099 - Val: 0.12667 (Best Fold: 0.11795)
#     Early stopping at epoch 516. Best Val Loss for Fold: 0.11795
#   --- Fold 2 finished. Best Val Loss: 0.11795 ---
#   --- Fold 3/5 for seq_len: 30 ---
#   Training sequences: 776, Validation sequences: 194
#     Epoch 200/5000 - Train: 0.23311 - Val: 0.23511 (Best Fold: 0.23511)
#     Epoch 400/5000 - Train: 0.10370 - Val: 0.09634 (Best Fold: 0.09634)
#     Epoch 600/5000 - Train: 0.05772 - Val: 0.04726 (Best Fold: 0.04430)
#     Epoch 636/5000 - Train: 0.06018 - Val: 0.05098 (Best Fold: 0.04295)
#     Early stopping at epoch 636. Best Val Loss for Fold: 0.04295
#   --- Fold 3 finished. Best Val Loss: 0.04295 ---
#   --- Fold 4/5 for seq_len: 30 ---
#   Training sequences: 776, Validation sequences: 194
#     Epoch 172/5000 - Train: 0.26112 - Val: 0.21149 (Best Fold: 0.21005)
#     Early stopping at epoch 172. Best Val Loss for Fold: 0.21005
#   --- Fold 4 finished. Best Val Loss: 0.21005 ---
#   --- Fold 5/5 for seq_len: 30 ---
#   Training sequences: 776, Validation sequences: 194
#     Epoch 200/5000 - Train: 0.23006 - Val: 0.21902 (Best Fold: 0.21902)
#     Epoch 400/5000 - Train: 0.11914 - Val: 0.05838 (Best Fold: 0.05838)
#     Epoch 600/5000 - Train: 0.06728 - Val: 0.03105 (Best Fold: 0.03105)
#     Epoch 645/5000 - Train: 0.06317 - Val: 0.03243 (Best Fold: 0.03023)
#     Early stopping at epoch 645. Best Val Loss for Fold: 0.03023
#   --- Fold 5 finished. Best Val Loss: 0.03023 ---
# --- Finished seq_len: 30. Mean Val Loss: 0.10041 (Std: 0.06412) ---
#
# --- Evaluating seq_len: 32 ---
#   Total sequences for seq_len 32: 968
#   --- Fold 1/5 for seq_len: 32 ---
#   Training sequences: 774, Validation sequences: 194
#     Epoch 200/5000 - Train: 0.23353 - Val: 0.18074 (Best Fold: 0.18074)
#     Epoch 400/5000 - Train: 0.09216 - Val: 0.05998 (Best Fold: 0.05968)
#     Epoch 580/5000 - Train: 0.05906 - Val: 0.04687 (Best Fold: 0.04537)
#     Early stopping at epoch 580. Best Val Loss for Fold: 0.04537
#   --- Fold 1 finished. Best Val Loss: 0.04537 ---
#   --- Fold 2/5 for seq_len: 32 ---
#   Training sequences: 774, Validation sequences: 194
#     Epoch 200/5000 - Train: 0.24163 - Val: 0.19818 (Best Fold: 0.19818)
#     Epoch 400/5000 - Train: 0.10003 - Val: 0.06171 (Best Fold: 0.06171)
#     Epoch 421/5000 - Train: 0.08574 - Val: 0.06132 (Best Fold: 0.06075)
#     Early stopping at epoch 421. Best Val Loss for Fold: 0.06075
#   --- Fold 2 finished. Best Val Loss: 0.06075 ---
#   --- Fold 3/5 for seq_len: 32 ---
#   Training sequences: 774, Validation sequences: 194
#     Epoch 200/5000 - Train: 0.22345 - Val: 0.24806 (Best Fold: 0.24806)
#     Epoch 400/5000 - Train: 0.10133 - Val: 0.07791 (Best Fold: 0.07791)
#     Epoch 594/5000 - Train: 0.06002 - Val: 0.04049 (Best Fold: 0.03455)
#     Early stopping at epoch 594. Best Val Loss for Fold: 0.03455
#   --- Fold 3 finished. Best Val Loss: 0.03455 ---
#   --- Fold 4/5 for seq_len: 32 ---
#   Training sequences: 775, Validation sequences: 193
#     Epoch 200/5000 - Train: 0.24274 - Val: 0.21122 (Best Fold: 0.21122)
#     Epoch 400/5000 - Train: 0.08712 - Val: 0.16933 (Best Fold: 0.16915)
#     Epoch 467/5000 - Train: 0.06300 - Val: 0.16826 (Best Fold: 0.16672)
#     Early stopping at epoch 467. Best Val Loss for Fold: 0.16672
#   --- Fold 4 finished. Best Val Loss: 0.16672 ---
#   --- Fold 5/5 for seq_len: 32 ---
#   Training sequences: 775, Validation sequences: 193
#     Epoch 200/5000 - Train: 0.24844 - Val: 0.33937 (Best Fold: 0.33937)
#     Epoch 400/5000 - Train: 0.08507 - Val: 0.13563 (Best Fold: 0.13554)
#     Epoch 423/5000 - Train: 0.08413 - Val: 0.13821 (Best Fold: 0.13460)
#     Early stopping at epoch 423. Best Val Loss for Fold: 0.13460
#   --- Fold 5 finished. Best Val Loss: 0.13460 ---
# --- Finished seq_len: 32. Mean Val Loss: 0.08840 (Std: 0.05251) ---
#
# --- Evaluating seq_len: 35 ---
#   Total sequences for seq_len 35: 965
#   --- Fold 1/5 for seq_len: 35 ---
#   Training sequences: 772, Validation sequences: 193
#     Epoch 200/5000 - Train: 0.23270 - Val: 0.16373 (Best Fold: 0.16373)
#     Epoch 400/5000 - Train: 0.10702 - Val: 0.04325 (Best Fold: 0.04310)
#     Epoch 455/5000 - Train: 0.10469 - Val: 0.03935 (Best Fold: 0.03788)
#     Early stopping at epoch 455. Best Val Loss for Fold: 0.03788
#   --- Fold 1 finished. Best Val Loss: 0.03788 ---
#   --- Fold 2/5 for seq_len: 35 ---
#   Training sequences: 772, Validation sequences: 193
#     Epoch 200/5000 - Train: 0.21292 - Val: 0.25365 (Best Fold: 0.25365)
#     Epoch 400/5000 - Train: 0.09385 - Val: 0.12941 (Best Fold: 0.12941)
#     Epoch 587/5000 - Train: 0.06212 - Val: 0.07818 (Best Fold: 0.07497)
#     Early stopping at epoch 587. Best Val Loss for Fold: 0.07497
#   --- Fold 2 finished. Best Val Loss: 0.07497 ---
#   --- Fold 3/5 for seq_len: 35 ---
#   Training sequences: 772, Validation sequences: 193
#     Epoch 200/5000 - Train: 0.20902 - Val: 0.25297 (Best Fold: 0.25297)
#     Epoch 400/5000 - Train: 0.07999 - Val: 0.14805 (Best Fold: 0.14784)
#     Epoch 590/5000 - Train: 0.05306 - Val: 0.11191 (Best Fold: 0.10465)
#     Early stopping at epoch 590. Best Val Loss for Fold: 0.10465
#   --- Fold 3 finished. Best Val Loss: 0.10465 ---
#   --- Fold 4/5 for seq_len: 35 ---
#   Training sequences: 772, Validation sequences: 193
#     Epoch 200/5000 - Train: 0.22092 - Val: 0.21171 (Best Fold: 0.21171)
#     Epoch 400/5000 - Train: 0.09359 - Val: 0.08013 (Best Fold: 0.07864)
#     Epoch 600/5000 - Train: 0.06924 - Val: 0.03942 (Best Fold: 0.03818)
#     Epoch 645/5000 - Train: 0.04492 - Val: 0.04866 (Best Fold: 0.03386)
#     Early stopping at epoch 645. Best Val Loss for Fold: 0.03386
#   --- Fold 4 finished. Best Val Loss: 0.03386 ---
#   --- Fold 5/5 for seq_len: 35 ---
#   Training sequences: 772, Validation sequences: 193
#     Epoch 200/5000 - Train: 0.25586 - Val: 0.24145 (Best Fold: 0.24145)
#     Epoch 400/5000 - Train: 0.10315 - Val: 0.09136 (Best Fold: 0.09020)
#     Epoch 405/5000 - Train: 0.11421 - Val: 0.09147 (Best Fold: 0.09020)
#     Early stopping at epoch 405. Best Val Loss for Fold: 0.09020
#   --- Fold 5 finished. Best Val Loss: 0.09020 ---
# --- Finished seq_len: 35. Mean Val Loss: 0.06831 (Std: 0.02813) ---
#
# --- Evaluating seq_len: 37 ---
#   Total sequences for seq_len 37: 963
#   --- Fold 1/5 for seq_len: 37 ---
#   Training sequences: 770, Validation sequences: 193
#     Epoch 200/5000 - Train: 0.23634 - Val: 0.22853 (Best Fold: 0.22853)
#     Epoch 328/5000 - Train: 0.11590 - Val: 0.12673 (Best Fold: 0.11158)
#     Early stopping at epoch 328. Best Val Loss for Fold: 0.11158
#   --- Fold 1 finished. Best Val Loss: 0.11158 ---
#   --- Fold 2/5 for seq_len: 37 ---
#   Training sequences: 770, Validation sequences: 193
#     Epoch 200/5000 - Train: 0.22585 - Val: 0.19810 (Best Fold: 0.19810)
#     Epoch 400/5000 - Train: 0.11112 - Val: 0.04739 (Best Fold: 0.04739)
#     Epoch 600/5000 - Train: 0.05464 - Val: 0.02072 (Best Fold: 0.02046)
#     Epoch 655/5000 - Train: 0.04775 - Val: 0.02150 (Best Fold: 0.01787)
#     Early stopping at epoch 655. Best Val Loss for Fold: 0.01787
#   --- Fold 2 finished. Best Val Loss: 0.01787 ---
#   --- Fold 3/5 for seq_len: 37 ---
#   Training sequences: 770, Validation sequences: 193
#     Epoch 200/5000 - Train: 0.26035 - Val: 0.14169 (Best Fold: 0.14169)
#     Epoch 328/5000 - Train: 0.12474 - Val: 0.08330 (Best Fold: 0.07901)
#     Early stopping at epoch 328. Best Val Loss for Fold: 0.07901
#   --- Fold 3 finished. Best Val Loss: 0.07901 ---
#   --- Fold 4/5 for seq_len: 37 ---
#   Training sequences: 771, Validation sequences: 192
#     Epoch 200/5000 - Train: 0.22752 - Val: 0.20469 (Best Fold: 0.20469)
#     Epoch 400/5000 - Train: 0.09761 - Val: 0.09698 (Best Fold: 0.09585)
#     Epoch 600/5000 - Train: 0.04539 - Val: 0.06924 (Best Fold: 0.06503)
#     Epoch 689/5000 - Train: 0.04766 - Val: 0.06067 (Best Fold: 0.05816)
#     Early stopping at epoch 689. Best Val Loss for Fold: 0.05816
#   --- Fold 4 finished. Best Val Loss: 0.05816 ---
#   --- Fold 5/5 for seq_len: 37 ---
#   Training sequences: 771, Validation sequences: 192
#     Epoch 200/5000 - Train: 0.18844 - Val: 0.35756 (Best Fold: 0.35756)
#     Epoch 400/5000 - Train: 0.09030 - Val: 0.20182 (Best Fold: 0.20182)
#     Epoch 555/5000 - Train: 0.05962 - Val: 0.16808 (Best Fold: 0.16775)
#     Early stopping at epoch 555. Best Val Loss for Fold: 0.16775
#   --- Fold 5 finished. Best Val Loss: 0.16775 ---
# --- Finished seq_len: 37. Mean Val Loss: 0.08687 (Std: 0.05060) ---
#
# --- Evaluating seq_len: 40 ---
#   Total sequences for seq_len 40: 960
#   --- Fold 1/5 for seq_len: 40 ---
#   Training sequences: 768, Validation sequences: 192
#     Epoch 200/5000 - Train: 0.20949 - Val: 0.22850 (Best Fold: 0.22850)
#     Epoch 400/5000 - Train: 0.08882 - Val: 0.06490 (Best Fold: 0.06490)
#     Epoch 473/5000 - Train: 0.06871 - Val: 0.05379 (Best Fold: 0.04930)
#     Early stopping at epoch 473. Best Val Loss for Fold: 0.04930
#   --- Fold 1 finished. Best Val Loss: 0.04930 ---
#   --- Fold 2/5 for seq_len: 40 ---
#   Training sequences: 768, Validation sequences: 192
#     Epoch 200/5000 - Train: 0.25476 - Val: 0.21526 (Best Fold: 0.21526)
#     Epoch 400/5000 - Train: 0.08642 - Val: 0.06039 (Best Fold: 0.05522)
#     Epoch 440/5000 - Train: 0.07126 - Val: 0.05291 (Best Fold: 0.04823)
#     Early stopping at epoch 440. Best Val Loss for Fold: 0.04823
#   --- Fold 2 finished. Best Val Loss: 0.04823 ---
#   --- Fold 3/5 for seq_len: 40 ---
#   Training sequences: 768, Validation sequences: 192
#     Epoch 200/5000 - Train: 0.22532 - Val: 0.22731 (Best Fold: 0.22731)
#     Epoch 400/5000 - Train: 0.08775 - Val: 0.07670 (Best Fold: 0.07652)
#     Epoch 462/5000 - Train: 0.07626 - Val: 0.07484 (Best Fold: 0.06529)
#     Early stopping at epoch 462. Best Val Loss for Fold: 0.06529
#   --- Fold 3 finished. Best Val Loss: 0.06529 ---
#   --- Fold 4/5 for seq_len: 40 ---
#   Training sequences: 768, Validation sequences: 192
#     Epoch 200/5000 - Train: 0.24446 - Val: 0.16144 (Best Fold: 0.15316)
#     Early stopping at epoch 200. Best Val Loss for Fold: 0.15316
#   --- Fold 4 finished. Best Val Loss: 0.15316 ---
#   --- Fold 5/5 for seq_len: 40 ---
#   Training sequences: 768, Validation sequences: 192
#     Epoch 200/5000 - Train: 0.26396 - Val: 0.32960 (Best Fold: 0.32960)
#     Epoch 315/5000 - Train: 0.11995 - Val: 0.24690 (Best Fold: 0.19811)
#     Early stopping at epoch 315. Best Val Loss for Fold: 0.19811
#   --- Fold 5 finished. Best Val Loss: 0.19811 ---
# --- Finished seq_len: 40. Mean Val Loss: 0.10282 (Std: 0.06143) ---
#
# --- Evaluating seq_len: 42 ---
#   Total sequences for seq_len 42: 958
#   --- Fold 1/5 for seq_len: 42 ---
#   Training sequences: 766, Validation sequences: 192
#     Epoch 200/5000 - Train: 0.22230 - Val: 0.24773 (Best Fold: 0.24773)
#     Epoch 400/5000 - Train: 0.08783 - Val: 0.12305 (Best Fold: 0.12305)
#     Epoch 457/5000 - Train: 0.07173 - Val: 0.11855 (Best Fold: 0.11382)
#     Early stopping at epoch 457. Best Val Loss for Fold: 0.11382
#   --- Fold 1 finished. Best Val Loss: 0.11382 ---
#   --- Fold 2/5 for seq_len: 42 ---
#   Training sequences: 766, Validation sequences: 192
#     Epoch 200/5000 - Train: 0.23757 - Val: 0.28761 (Best Fold: 0.28761)
#     Epoch 400/5000 - Train: 0.08702 - Val: 0.09310 (Best Fold: 0.08453)
#     Epoch 474/5000 - Train: 0.05778 - Val: 0.07651 (Best Fold: 0.07029)
#     Early stopping at epoch 474. Best Val Loss for Fold: 0.07029
#   --- Fold 2 finished. Best Val Loss: 0.07029 ---
#   --- Fold 3/5 for seq_len: 42 ---
#   Training sequences: 766, Validation sequences: 192
#     Epoch 200/5000 - Train: 0.23606 - Val: 0.29003 (Best Fold: 0.29003)
#     Epoch 400/5000 - Train: 0.07049 - Val: 0.13189 (Best Fold: 0.13189)
#     Epoch 600/5000 - Train: 0.04564 - Val: 0.10501 (Best Fold: 0.10098)
#     Epoch 745/5000 - Train: 0.03427 - Val: 0.07745 (Best Fold: 0.07344)
#     Early stopping at epoch 745. Best Val Loss for Fold: 0.07344
#   --- Fold 3 finished. Best Val Loss: 0.07344 ---
#   --- Fold 4/5 for seq_len: 42 ---
#   Training sequences: 767, Validation sequences: 191
#     Epoch 200/5000 - Train: 0.26107 - Val: 0.13602 (Best Fold: 0.13602)
#     Epoch 400/5000 - Train: 0.10592 - Val: 0.05244 (Best Fold: 0.05203)
#     Epoch 513/5000 - Train: 0.07836 - Val: 0.04277 (Best Fold: 0.04172)
#     Early stopping at epoch 513. Best Val Loss for Fold: 0.04172
#   --- Fold 4 finished. Best Val Loss: 0.04172 ---
#   --- Fold 5/5 for seq_len: 42 ---
#   Training sequences: 767, Validation sequences: 191
#     Epoch 200/5000 - Train: 0.24931 - Val: 0.24900 (Best Fold: 0.24900)
#     Epoch 400/5000 - Train: 0.10020 - Val: 0.11175 (Best Fold: 0.11064)
#     Epoch 406/5000 - Train: 0.10180 - Val: 0.11346 (Best Fold: 0.11064)
#     Early stopping at epoch 406. Best Val Loss for Fold: 0.11064
#   --- Fold 5 finished. Best Val Loss: 0.11064 ---
# --- Finished seq_len: 42. Mean Val Loss: 0.08198 (Std: 0.02708) ---
#
# --- Evaluating seq_len: 45 ---
#   Total sequences for seq_len 45: 955
#   --- Fold 1/5 for seq_len: 45 ---
#   Training sequences: 764, Validation sequences: 191
#     Epoch 200/5000 - Train: 0.22584 - Val: 0.19990 (Best Fold: 0.19990)
#     Epoch 336/5000 - Train: 0.12262 - Val: 0.11512 (Best Fold: 0.10460)
#     Early stopping at epoch 336. Best Val Loss for Fold: 0.10460
#   --- Fold 1 finished. Best Val Loss: 0.10460 ---
#   --- Fold 2/5 for seq_len: 45 ---
#   Training sequences: 764, Validation sequences: 191
#     Epoch 200/5000 - Train: 0.24334 - Val: 0.15161 (Best Fold: 0.15132)
#     Epoch 400/5000 - Train: 0.10326 - Val: 0.06376 (Best Fold: 0.06346)
#     Epoch 600/5000 - Train: 0.05122 - Val: 0.02519 (Best Fold: 0.02515)
#     Epoch 665/5000 - Train: 0.04370 - Val: 0.02691 (Best Fold: 0.02155)
#     Early stopping at epoch 665. Best Val Loss for Fold: 0.02155
#   --- Fold 2 finished. Best Val Loss: 0.02155 ---
#   --- Fold 3/5 for seq_len: 45 ---
#   Training sequences: 764, Validation sequences: 191
#     Epoch 200/5000 - Train: 0.24335 - Val: 0.22149 (Best Fold: 0.22149)
#     Epoch 400/5000 - Train: 0.09439 - Val: 0.08716 (Best Fold: 0.08439)
#     Epoch 429/5000 - Train: 0.09143 - Val: 0.08267 (Best Fold: 0.08025)
#     Early stopping at epoch 429. Best Val Loss for Fold: 0.08025
#   --- Fold 3 finished. Best Val Loss: 0.08025 ---
#   --- Fold 4/5 for seq_len: 45 ---
#   Training sequences: 764, Validation sequences: 191
#     Epoch 200/5000 - Train: 0.25322 - Val: 0.18876 (Best Fold: 0.18876)
#     Epoch 400/5000 - Train: 0.11288 - Val: 0.07117 (Best Fold: 0.07117)
#     Epoch 600/5000 - Train: 0.06169 - Val: 0.03934 (Best Fold: 0.03224)
#     Epoch 641/5000 - Train: 0.06057 - Val: 0.04021 (Best Fold: 0.02899)
#     Early stopping at epoch 641. Best Val Loss for Fold: 0.02899
#   --- Fold 4 finished. Best Val Loss: 0.02899 ---
#   --- Fold 5/5 for seq_len: 45 ---
#   Training sequences: 764, Validation sequences: 191
#     Epoch 200/5000 - Train: 0.19033 - Val: 0.40122 (Best Fold: 0.40122)
#     Epoch 400/5000 - Train: 0.07658 - Val: 0.24546 (Best Fold: 0.24258)
#     Epoch 477/5000 - Train: 0.05474 - Val: 0.22766 (Best Fold: 0.22190)
#     Early stopping at epoch 477. Best Val Loss for Fold: 0.22190
#   --- Fold 5 finished. Best Val Loss: 0.22190 ---
# --- Finished seq_len: 45. Mean Val Loss: 0.09146 (Std: 0.07225) ---
#
# --- Evaluating seq_len: 47 ---
#   Total sequences for seq_len 47: 953
#   --- Fold 1/5 for seq_len: 47 ---
#   Training sequences: 762, Validation sequences: 191
#     Epoch 200/5000 - Train: 0.24336 - Val: 0.22464 (Best Fold: 0.22464)
#     Epoch 400/5000 - Train: 0.10424 - Val: 0.10343 (Best Fold: 0.10338)
#     Epoch 600/5000 - Train: 0.05005 - Val: 0.06788 (Best Fold: 0.06788)
#     Epoch 697/5000 - Train: 0.03956 - Val: 0.06190 (Best Fold: 0.05283)
#     Early stopping at epoch 697. Best Val Loss for Fold: 0.05283
#   --- Fold 1 finished. Best Val Loss: 0.05283 ---
#   --- Fold 2/5 for seq_len: 47 ---
#   Training sequences: 762, Validation sequences: 191
#     Epoch 200/5000 - Train: 0.24508 - Val: 0.19023 (Best Fold: 0.19023)
#     Epoch 400/5000 - Train: 0.11220 - Val: 0.03686 (Best Fold: 0.03655)
#     Epoch 600/5000 - Train: 0.07177 - Val: 0.01879 (Best Fold: 0.01844)
#     Epoch 800/5000 - Train: 0.04900 - Val: 0.01179 (Best Fold: 0.01178)
#     Epoch 837/5000 - Train: 0.03877 - Val: 0.01184 (Best Fold: 0.01122)
#     Early stopping at epoch 837. Best Val Loss for Fold: 0.01122
#   --- Fold 2 finished. Best Val Loss: 0.01122 ---
#   --- Fold 3/5 for seq_len: 47 ---
#   Training sequences: 762, Validation sequences: 191
#     Epoch 200/5000 - Train: 0.26791 - Val: 0.15993 (Best Fold: 0.15993)
#     Epoch 400/5000 - Train: 0.08991 - Val: 0.04997 (Best Fold: 0.03645)
#     Epoch 406/5000 - Train: 0.08881 - Val: 0.05214 (Best Fold: 0.03645)
#     Early stopping at epoch 406. Best Val Loss for Fold: 0.03645
#   --- Fold 3 finished. Best Val Loss: 0.03645 ---
#   --- Fold 4/5 for seq_len: 47 ---
#   Training sequences: 763, Validation sequences: 190
#     Epoch 200/5000 - Train: 0.25446 - Val: 0.15717 (Best Fold: 0.15717)
#     Epoch 328/5000 - Train: 0.11706 - Val: 0.09541 (Best Fold: 0.09010)
#     Early stopping at epoch 328. Best Val Loss for Fold: 0.09010
#   --- Fold 4 finished. Best Val Loss: 0.09010 ---
#   --- Fold 5/5 for seq_len: 47 ---
#   Training sequences: 763, Validation sequences: 190
#     Epoch 200/5000 - Train: 0.20460 - Val: 0.45782 (Best Fold: 0.45782)
#     Epoch 400/5000 - Train: 0.05223 - Val: 0.24943 (Best Fold: 0.24581)
#     Epoch 561/5000 - Train: 0.03387 - Val: 0.19016 (Best Fold: 0.16711)
#     Early stopping at epoch 561. Best Val Loss for Fold: 0.16711
#   --- Fold 5 finished. Best Val Loss: 0.16711 ---
# --- Finished seq_len: 47. Mean Val Loss: 0.07154 (Std: 0.05422) ---
#
# --- Evaluating seq_len: 50 ---
#   Total sequences for seq_len 50: 950
#   --- Fold 1/5 for seq_len: 50 ---
#   Training sequences: 760, Validation sequences: 190
#     Epoch 200/5000 - Train: 0.28973 - Val: 0.18174 (Best Fold: 0.18174)
#     Epoch 400/5000 - Train: 0.10384 - Val: 0.05088 (Best Fold: 0.05016)
#     Epoch 429/5000 - Train: 0.09852 - Val: 0.05233 (Best Fold: 0.04783)
#     Early stopping at epoch 429. Best Val Loss for Fold: 0.04783
#   --- Fold 1 finished. Best Val Loss: 0.04783 ---
#   --- Fold 2/5 for seq_len: 50 ---
#   Training sequences: 760, Validation sequences: 190
#     Epoch 200/5000 - Train: 0.20473 - Val: 0.34303 (Best Fold: 0.34303)
#     Epoch 400/5000 - Train: 0.08259 - Val: 0.17063 (Best Fold: 0.16789)
#     Epoch 600/5000 - Train: 0.04435 - Val: 0.08158 (Best Fold: 0.07556)
#     Epoch 707/5000 - Train: 0.03638 - Val: 0.05144 (Best Fold: 0.04924)
#     Early stopping at epoch 707. Best Val Loss for Fold: 0.04924
#   --- Fold 2 finished. Best Val Loss: 0.04924 ---
#   --- Fold 3/5 for seq_len: 50 ---
#   Training sequences: 760, Validation sequences: 190
#     Epoch 200/5000 - Train: 0.23730 - Val: 0.20758 (Best Fold: 0.20758)
#     Epoch 400/5000 - Train: 0.09990 - Val: 0.09522 (Best Fold: 0.09105)
#     Epoch 406/5000 - Train: 0.10047 - Val: 0.09601 (Best Fold: 0.09105)
#     Early stopping at epoch 406. Best Val Loss for Fold: 0.09105
#   --- Fold 3 finished. Best Val Loss: 0.09105 ---
#   --- Fold 4/5 for seq_len: 50 ---
#   Training sequences: 760, Validation sequences: 190
#     Epoch 200/5000 - Train: 0.26424 - Val: 0.11669 (Best Fold: 0.11669)
#     Epoch 400/5000 - Train: 0.10972 - Val: 0.02060 (Best Fold: 0.02040)
#     Epoch 600/5000 - Train: 0.07233 - Val: 0.00857 (Best Fold: 0.00815)
#     Epoch 643/5000 - Train: 0.07297 - Val: 0.00917 (Best Fold: 0.00762)
#     Early stopping at epoch 643. Best Val Loss for Fold: 0.00762
#   --- Fold 4 finished. Best Val Loss: 0.00762 ---
#   --- Fold 5/5 for seq_len: 50 ---
#   Training sequences: 760, Validation sequences: 190
#     Epoch 200/5000 - Train: 0.20728 - Val: 0.29186 (Best Fold: 0.29186)
#     Epoch 396/5000 - Train: 0.05601 - Val: 0.23370 (Best Fold: 0.23047)
#     Early stopping at epoch 396. Best Val Loss for Fold: 0.23047
#   --- Fold 5 finished. Best Val Loss: 0.23047 ---
# --- Finished seq_len: 50. Mean Val Loss: 0.08524 (Std: 0.07726) ---
#
# --- Hyperparameter Tuning Complete (K-Fold CV) ---
# All results:
#   Seq_len:  20 -> Mean: 0.07757, Std: 0.03809, Fold Losses: ['0.14985', '0.08152', '0.04503', '0.05501', '0.05643']
#   Seq_len:  22 -> Mean: 0.05021, Std: 0.02426, Fold Losses: ['0.09326', '0.06006', '0.03470', '0.03661', '0.02642']
#   Seq_len:  25 -> Mean: 0.06358, Std: 0.01604, Fold Losses: ['0.08497', '0.04027', '0.06072', '0.07748', '0.05445']
#   Seq_len:  27 -> Mean: 0.05606, Std: 0.03260, Fold Losses: ['0.11660', '0.03403', '0.02772', '0.03856', '0.06338']
#   Seq_len:  30 -> Mean: 0.10041, Std: 0.06412, Fold Losses: ['0.10085', '0.11795', '0.04295', '0.21005', '0.03023']
#   Seq_len:  32 -> Mean: 0.08840, Std: 0.05251, Fold Losses: ['0.04537', '0.06075', '0.03455', '0.16672', '0.13460']
#   Seq_len:  35 -> Mean: 0.06831, Std: 0.02813, Fold Losses: ['0.03788', '0.07497', '0.10465', '0.03386', '0.09020']
#   Seq_len:  37 -> Mean: 0.08687, Std: 0.05060, Fold Losses: ['0.11158', '0.01787', '0.07901', '0.05816', '0.16775']
#   Seq_len:  40 -> Mean: 0.10282, Std: 0.06143, Fold Losses: ['0.04930', '0.04823', '0.06529', '0.15316', '0.19811']
#   Seq_len:  42 -> Mean: 0.08198, Std: 0.02708, Fold Losses: ['0.11382', '0.07029', '0.07344', '0.04172', '0.11064']
#   Seq_len:  45 -> Mean: 0.09146, Std: 0.07225, Fold Losses: ['0.10460', '0.02155', '0.08025', '0.02899', '0.22190']
#   Seq_len:  47 -> Mean: 0.07154, Std: 0.05422, Fold Losses: ['0.05283', '0.01122', '0.03645', '0.09010', '0.16711']
#   Seq_len:  50 -> Mean: 0.08524, Std: 0.07726, Fold Losses: ['0.04783', '0.04924', '0.09105', '0.00762', '0.23047']
#
# Best sequence length: 22
# Lowest mean validation loss: 0.05021

# %%
# Plot the validation losses for each sequence length
plt.figure(figsize=(10, 6))

# Prepare data for plotting
seq_lengths = []
mean_losses = []
std_losses = []
individual_losses = []

# Extract data from hyperparameter_tuning_results
for seq_len, results in sorted(hyperparameter_tuning_results.items()):
    seq_lengths.append(seq_len)
    mean_losses.append(results['mean_best_val_loss'])
    std_losses.append(results['std_best_val_loss'])
    individual_losses.append(results['individual_trial_losses'])

# Plot mean validation loss with error bars
plt.errorbar(seq_lengths, mean_losses, yerr=std_losses, fmt='o-', capsize=5, 
             label='Mean Validation Loss', color='blue', markersize=8)

# Plot individual trial losses for each sequence length
for i, (seq_len, trials) in enumerate(zip(seq_lengths, individual_losses)):
    # Create slight horizontal offset for better visibility
    x_jittered = [seq_len + (j - len(trials)/2) * 0.2 for j in range(len(trials))]
    plt.scatter(x_jittered, trials, color='red', alpha=0.5, s=30)

# Highlight the best sequence length
if best_seq_len_final is not None:
    best_idx = seq_lengths.index(best_seq_len_final)
    plt.scatter(seq_lengths[best_idx], mean_losses[best_idx], color='green', 
                s=200, marker='*', label=f'Best Seq Length: {best_seq_len_final}')

# Add labels and title
plt.xlabel('Sequence Length')
plt.ylabel('Validation Loss')
plt.title('Validation Loss vs. Sequence Length')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()

# Ensure x-axis shows all sequence lengths
plt.xticks(seq_lengths)

plt.tight_layout()
plt.show()
